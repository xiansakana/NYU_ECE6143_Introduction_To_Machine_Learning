# %% [markdown]
# ## Deep Neural Nets: 33 years ago and 33 years from now
#
# _Fraida Fund_
#
# ---
#
# **Attribution**: This notebook is adapted from the ICLR 2022 blog post ["Deep Neural Nets: 33 years ago and 33 years from now"](https://iclr-blog-track.github.io/2022/03/26/lecun1989/)  by Andrej Karpathy, and the associated [Github repository](https://github.com/karpathy/lecun1989-repro). It was adapted for this format with the help of Chen Yang.

# %% [markdown]
# ###  Introduction

# %% [markdown]
# In an earlier lesson, we introduced a 1960s-era solution to the problem of handwritten digit recognition, described in the paper
#
# > E. C. Greanias, P. F. Meagher, R. J. Norman and P. Essinger, "The Recognition of Handwritten Numerals by Contour Analysis," in IBM Journal of Research and Development, vol. 7, no. 1, pp. 14-21, Jan. 1963, doi: 10.1147/rd.71.0014.
#
# In that case, we said, the approach was _not_ a machine learning one - both the "features" and the "rules" were hand-crafted by the engineers. The accuracy of this system (on digits by "untrained" writers) was about 92%.

# %% [markdown]
# Fast forward about ~35 years, and a neural network with 3 hidden layers, trained with backpropagation, solved the handwritten digit recognition problem with a 95% accuracy on a test set not used for model training. This work is described in the paper
#
# > Y. LeCun et al., "Backpropagation Applied to Handwritten Zip Code Recognition," in Neural Computation, vol. 1, no. 4, pp. 541-551, Dec. 1989, doi: 10.1162/neco.1989.1.4.541.
#
# which you can access [here](https://direct.mit.edu/neco/article/1/4/541/5515/Backpropagation-Applied-to-Handwritten-Zip-Code).

# %% [markdown]
# In fact, according to the caption of the demo video below, "At some point in the late 90's these machines \[implementing the approach described in this paper\] were processing 10 to 20% of all the checks in the US" in order to read the numerical amount on the check.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('FwFduRA_L6Q')

# %% [markdown]
# In this notebook, we will try to reproduce the results of the 1989 paper, by following its approach as closely as possible. Then, we'll try to improve on it using a few more modern techniques for deep neural networks.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import datasets

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Retrieve and preprocess data

# %% [markdown]
# The original paper explains how the handwritten digit dataset was acquired and preprocessed:
#
# > **2.1 Data Base.** The data base used to train and test the networks consists of 9298 segmented numerals digitized from handwritten zip codes that appeared on U.S. mail passing through the Buffalo, NY post office. Examples of such images are shown in Figure 1. The digits were written by many different people, using a great variety of sizes, writing styles, and instruments, with widely varying amounts of care; 7291 examples are used for training the network and 2007 are used for testing the generalization performance. One important feature of this data base is that both the training set and the testing set contain numerous examples that are ambiguous, unclassifiable, or even misclassified.
# >
# > **2.2 Preprocessing.** Locating the zip code on the envelope and separating each digit from its neighbors, a very hard task in itself, was performed by Postal Service contractors (Wang and Srihari 1988). At this point, the size of a digit image varies but is typically around 40 by 60 pixels. A linear transformation is then applied to make the image fit in a 16 by 16 pixel image. This transformation preserves the aspect ratio of the character, and is performed after extraneous marks in the image have been removed. Because of the linear transformation, the resulting image is not binary but has multiple gray levels, since a variable number of pixels in the original image can fall into a given pixel in the target image. The gray levels of each image are scaled and translated to fall within the range -1 to 1.

# %% [markdown]
# Since we don't have this exact data set, we take MNIST - a very similar data set! - and use it as an approximation of the original data set. MNIST is different in a few ways.
#
# * has 50,000 training samples, and 10,000 test samples (compared to 7291 and 2007 respectively, for the original paper),
# * and each sample is 28x28 pixels (compared to 16x16 for the original)
#
# so to "simulate" the original, we sample without replacement the correct number of training and test samples from the complete MNIST and scale them down to the smaller 16x16 size.

# %% [markdown]
# ---
#
# 🛑 Since our data is not exactly the same as the original paper, the numeric results may also be slightly different.
#
# 🧪To explore how sensitive the numeric result is to the specific draw of training and test samples, you can try changing the seeds in the following cell and re-running!
#
# ---

# %%
# The following code is adapted from "prepro.py" in the repository.

torch.manual_seed(1337)
np.random.seed(1337)

for split in ['test', 'train']:

    data = datasets.MNIST('./data', train=split=='train', download=True)

    n = 7291 if split == 'train' else 2007
    rp = np.random.permutation(len(data))[:n]

    X = torch.full((n, 1, 16, 16), 0.0, dtype=torch.float32)
    Y = torch.full((n, 10), -1.0, dtype=torch.float32)
    for i, ix in enumerate(rp):
        I, yint = data[int(ix)]
        # PIL image -> numpy -> torch tensor -> [-1, 1] fp32
        xi = torch.from_numpy(np.array(I, dtype=np.float32)) / 127.5 - 1.0
        # add a fake batch dimension and a channel dimension of 1 or F.interpolate won't be happy
        xi = xi[None, None, ...]
        # resize to (16, 16) images with bilinear interpolation
        xi = F.interpolate(xi, (16, 16), mode='bilinear')
        X[i] = xi[0] # store

        # set the correct class to have target of +1.0
        Y[i, yint] = 1.0

    torch.save((X, Y), split + '1989.pt')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.8MB/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 475kB/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.39MB/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.11MB/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %% [markdown]
# The training and test datasets are now saved as 'train1989.pt' and 'test1989.pt', respectively.

# %% [markdown]
# ### Implement the original model

# %% [markdown]
# Now that we have data similar to the original training and evaluation data set, we can try to implement a model that is similar to the original.

# %% [markdown]
# The basic structure of the network design is described as follows in the original paper:
#
# > **3.1 Input and Output.** The remainder of the recognition is entirely performed by a multilayer network. All of the connections in the network are adaptive, although heavily constrained, and are trained using backpropagation. This is in contrast with earlier work (Denker _et al._ 1989) where the first few layers of connections were hand-chosen constants implemented on a neural-network chip. The input of the network is a 16 by 16 normalized image. The output is composed of 10 units (one per class) and uses place coding.

# %% [markdown]
# Next, the original paper motivates the convolutional units. Here are some selected excerpts:
#
# > **3.2 Feature Maps and Weight Sharing.** Classical work in visual pattern recognition has demonstrated the advantage of extracting local features and combining them to form higher order features. Such knowledge can be easily built into the network by forcing the hidden units to combine only local sources of information... The detection of a particular feature at any location on the input can be easily done using the "weight sharing" technique... Weight sharing not only greatly reduces the number of free parameters in the network but also can express information about the geometry
# and topology of the task.

# %% [markdown]
# Then, it describes the architecture of the hidden layers in more detail:
#
# > **3.3 Network Architecture.** The network is represented in Figure 2.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Its architecture is a direct extension of the one proposed in LeCun (1989). The network has three hidden layers named H1, H2, and H3 respectively. Connections entering H1 and H2 are local and are heavily constrained.
# >
# > H1 is composed of 12 groups of 64 units arranged as 12 independent
# 8 by 8 feature maps. These 12 feature maps will be designated by H1.l,
# H1.2, . . . , H1.12. Each unit in a feature map takes input on a 5 by 5
# neighborhood on the input plane. For units in layer H1 that are one
# unit apart, their receptive fields (in the input layer) are two pixels apart.
# Thus, the input image is undersampled and some position information is
# eliminated. A similar two-to-one undersampling occurs going from layer
# H1 to H2.
# >
# > Of course, units in another map (say H1.4) share another set of 25
# weights. Units do not share their biases (thresholds). Each unit thus has
# 25 input lines plus a bias. Connections extending past the boundaries of
# the input plane take their input from a virtual background plane whose state is equal to a constant, predetermined background level, in our case
# -1. Thus, layer H1 comprises 768 units (8 by 8 times 121, 19,968 connections (768 times 26), but only 1068 free parameters (768 biases plus 25
# times 12 feature kernels) since many connections share the same weight.
# >
# > Layer H2 is also composed of 12 features maps. Each feature map
# contains 16 units arranged in a 4 by 4 plane. As before, these feature
# maps will be designated as H2.1, H2.2, . . . ,H2.12. The connection scheme
# from  between H1 and H2 is quite similar to the one between the input and H1,
# but slightly more complicated because H1 has multiple two-dimensional
# maps. Each unit in H2 combines local information coming from 8 of the
# 12 different feature maps in H1. Its receptive field is composed of eight 5
# by 5 neighborhoods centered around units that are at identical positions
# within each of the eight maps. Thus, a unit in H2 has 200 inputs, 200
# weights, and a bias. Once again, all units in a given map are constrained
# to have identical weight vectors. The eight maps in H1 on which a map
# in H2 takes its inputs are chosen according a scheme that will not be
# described here. Connections falling off the boundaries are treated like
# as in H1. To summarize, layer H2 contains 192 units (12 times 4 by 4)
# and there is a total of 38,592 connections between layers H1 and H2 (192
# units times 201 input lines). All these connections are controlled by only
# 2592 free parameters (12 feature maps times 200 weights plus 192 biases).
# >
# > Layer H3 has 30 units, and is fully connected to H2. The number
# of connections between H2 and H3 is thus 5790 (30 times 192 plus 30
# biases). The output layer has 10 units and is also fully connected to H3,
# adding another 310 weights. In summary, the network has 1256 units,
# 64,660 connections, and 9760 independent parameters.

# %% [markdown]
# In modern terms, this describes a network with three hidden layers, H1, H2 and H3:
#
# * The input layer has 16\*16 units.
# * H1 has 12 5x5 convolutional kernels that move across the input with stride 2, and padding with the value -1 (for background). It is not exactly a "standard" convolutional layer, though, because the bias term is not shared (even within the same "filter"). Its output volume has dimension 12\*8\*8 and it has 1,068 parameters (768 biases + 25\*12 weights).
# * H2 similarly has 12 5x5 convolutional kernels, with stride 2 and padding as in H1. However, these connect to only 8 of the 12 input planes, in a pattern that is not specified in the original paper.  Its output volume has dimension 12\*4\*4 and it has 1,068 parameters (768 biases + 25\*12 weights).
# * H3 is a fully connected layer, and has 30 units fully connected to H2.
# * The output layer has  10 units fully connected to H3.

# %% [markdown]
# More details about the network are given in Section **4 Experimental Environment**:
#
# The activation function at each unit (including output units) is specified as tanh:
#
# > The nonlinear function used at each node was a scaled hyperbolic tangent.
#
# The loss function is mean squared error (which is not typically used for classification anymore!):
#
# > The output cost function was the mean squared error.
#
# The weight initialization scheme is specified as follows:
#
# > Before training, the weights were initialized with random values using a uniform distribution between -2.4/Fi and 2.4/Fi where Fi is the
# number of inputs (fan-in) of the unit to which the connection belongs.
# This technique tends to keep the total inputs within the operating range
# of the sigmoid.
#
# (Karpathy assumes in his implementation that this expression is accidentally missing a square root symbol, and there should be a square root on the fan-in.)

# %% [markdown]
# ---
#
# 🛑 Some details of the network - for example, the exact connection scheme between hidden layers - are not specified, so we have to guess at what the original authors might have done. Our guess might not be exactly right, so our numerical results might be different.
#
#
# 🛑 Since we don't have exactly the same random initial weights as the original paper, we won't necessarily see the exact same numeric result.
#
# 🧪To explore how sensitive the numeric result is to the specific initializations, you can try changing the seeds in the following cell and re-running!
#
# ---

# %%
# The following code is adapted from "repro.py" in the repository.

class BaseNet(nn.Module):
    """ 1989 LeCun ConvNet per description in the paper """

    def __init__(self):
        super().__init__()

        # initialization as described in the paper to my best ability, but it doesn't look right...
        winit = lambda fan_in, *shape: (torch.rand(*shape) - 0.5) * 2 * 2.4 / fan_in**0.5
        macs = 0 # keep track of MACs (multiply accumulates)
        acts = 0 # keep track of number of activations

        # H1 layer parameters and their initialization
        self.H1w = nn.Parameter(winit(5*5*1, 12, 1, 5, 5))
        self.H1b = nn.Parameter(torch.zeros(12, 8, 8)) # presumably init to zero for biases
        assert self.H1w.nelement() + self.H1b.nelement() == 1068
        macs += (5*5*1) * (8*8) * 12
        acts += (8*8) * 12

        # H2 layer parameters and their initialization
        """
        H2 neurons all connect to only 8 of the 12 input planes, with an unspecified pattern
        I am going to assume the most sensible block pattern where 4 planes at a time connect
        to differently overlapping groups of 8/12 input planes. We will implement this with 3
        separate convolutions that we concatenate the results of.
        """
        self.H2w = nn.Parameter(winit(5*5*8, 12, 8, 5, 5))
        self.H2b = nn.Parameter(torch.zeros(12, 4, 4)) # presumably init to zero for biases
        assert self.H2w.nelement() + self.H2b.nelement() == 2592
        macs += (5*5*8) * (4*4) * 12
        acts += (4*4) * 12

        # H3 is a fully connected layer
        self.H3w = nn.Parameter(winit(4*4*12, 4*4*12, 30))
        self.H3b = nn.Parameter(torch.zeros(30))
        assert self.H3w.nelement() + self.H3b.nelement() == 5790
        macs += (4*4*12) * 30
        acts += 30

        # output layer is also fully connected layer
        self.outw = nn.Parameter(winit(30, 30, 10))
        self.outb = nn.Parameter(-torch.ones(10)) # 9/10 targets are -1, so makes sense to init slightly towards it
        assert self.outw.nelement() + self.outb.nelement() == 310
        macs += 30 * 10
        acts += 10

        self.macs = macs
        self.acts = acts

    def forward(self, x):

        # x has shape (1, 1, 16, 16)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        x = F.conv2d(x, self.H1w, stride=2) + self.H1b
        x = torch.tanh(x)

        # x is now shape (1, 12, 8, 8)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        slice1 = F.conv2d(x[:, 0:8], self.H2w[0:4], stride=2) # first 4 planes look at first 8 input planes
        slice2 = F.conv2d(x[:, 4:12], self.H2w[4:8], stride=2) # next 4 planes look at last 8 input planes
        slice3 = F.conv2d(torch.cat((x[:, 0:4], x[:, 8:12]), dim=1), self.H2w[8:12], stride=2) # last 4 planes are cross
        x = torch.cat((slice1, slice2, slice3), dim=1) + self.H2b
        x = torch.tanh(x)

        # x is now shape (1, 12, 4, 4)
        x = x.flatten(start_dim=1) # (1, 12*4*4)
        x = x @ self.H3w + self.H3b
        x = torch.tanh(x)

        # x is now shape (1, 30)
        x = x @ self.outw + self.outb
        x = torch.tanh(x)

         # x is finally shape (1, 10)
        return x

# %% [markdown]
# ### Train the original model

# %% [markdown]
# Now, we are ready to train the model! The original paper specifies that the model is trained using SGD with one sample at a time:
#
# > During each learning experiment, the patterns were repeatedly presented in a constant order. The weights were updated according to the so-called stochastic gradient or "on-line" procedure (updating after each presentation of a single pattern) as opposed to the "true" gradient procedure (averaging over the whole training set before updating the weights).
#
# and that the network was trained for 23 epochs or "passes":
#
# > After each pass through the training set, the performance was measured both on the training and on the test set. The network was trained for 23 passes through the training set (167,693 pattern presentations).
#
# The learning rate is not specified in the original paper, and there is also no mention of learning rate decay - we assume that there was none used.

# %% [markdown]
# ---
#
# 🛑 Since the learning rate in the original work is not specified, and we select one somewhat arbitrarily (based on a few experiments), we won't necessarily see the exact same numeric result.
#
# 🧪To explore how sensitive the numeric result is to the specific learning rate, you can try changing the learning rate in the following cell and re-running!
#
# ---

# %%
# The following code is adapted from "repro.py" in the repository.

learning_rate = 0.03

# init rng
torch.manual_seed(1337)
np.random.seed(1337)
torch.use_deterministic_algorithms(True)

# init a model
model = BaseNet()
print("model stats:")
print("# params:      ", sum(p.numel() for p in model.parameters())) # in paper total is 9,760
print("# MACs:        ", model.macs)
print("# activations: ", model.acts)

# init data
Xtr, Ytr = torch.load('train1989.pt')
Xte, Yte = torch.load('test1989.pt')

# init optimizer
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

def eval_split(split):
    # eval the full train/test set, batched implementation for efficiency
    model.eval()
    X, Y = (Xtr, Ytr) if split == 'train' else (Xte, Yte)
    Yhat = model(X)
    loss = torch.mean((Y - Yhat)**2)
    err = torch.mean((Y.argmax(dim=1) != Yhat.argmax(dim=1)).float())
    print(f"eval: split {split:5s}. loss {loss.item():e}. error {err.item()*100:.2f}%. misses: {int(err.item()*Y.size(0))}")

# train
for pass_num in range(23):

    # perform one epoch of training
    model.train()
    for step_num in range(Xtr.size(0)):

        # fetch a single example into a batch of 1
        x, y = Xtr[[step_num]], Ytr[[step_num]]

        # forward the model and the loss
        yhat = model(x)
        loss = torch.mean((y - yhat)**2)

        # calculate the gradient and update the parameters
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # after epoch evaluate the train and test error / metrics
    print(pass_num + 1)
    eval_split('train')
    eval_split('test')

# save final model to file
torch.save(model.state_dict(), 'base_model.pt')
# Out:
# model stats:
# # params:       9760
# # MACs:         63660
# # activations:  1000
# <ipython-input-6-71077e02f4ce>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr, Ytr = torch.load('train1989.pt')
# <ipython-input-6-71077e02f4ce>:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte, Yte = torch.load('test1989.pt')
# 1
# eval: split train. loss 6.303314e-02. error 9.00%. misses: 656
# eval: split test . loss 6.877644e-02. error 10.26%. misses: 205
# 2
# eval: split train. loss 4.681421e-02. error 6.76%. misses: 492
# eval: split test . loss 5.422360e-02. error 8.37%. misses: 168
# 3
# eval: split train. loss 3.861542e-02. error 5.39%. misses: 392
# eval: split test . loss 4.878828e-02. error 7.57%. misses: 152
# 4
# eval: split train. loss 3.224056e-02. error 4.46%. misses: 325
# eval: split test . loss 4.432761e-02. error 7.27%. misses: 145
# 5
# eval: split train. loss 2.540203e-02. error 3.47%. misses: 252
# eval: split test . loss 4.001088e-02. error 5.68%. misses: 114
# 6
# eval: split train. loss 2.219604e-02. error 3.15%. misses: 229
# eval: split test . loss 3.938325e-02. error 5.68%. misses: 114
# 7
# eval: split train. loss 1.829774e-02. error 2.55%. misses: 185
# eval: split test . loss 3.681854e-02. error 5.33%. misses: 107
# 8
# eval: split train. loss 1.573309e-02. error 2.06%. misses: 149
# eval: split test . loss 3.523692e-02. error 5.03%. misses: 100
# 9
# eval: split train. loss 1.449435e-02. error 2.00%. misses: 145
# eval: split test . loss 3.441241e-02. error 5.13%. misses: 102
# 10
# eval: split train. loss 1.256489e-02. error 1.69%. misses: 122
# eval: split test . loss 3.318071e-02. error 4.93%. misses: 99
# 11
# eval: split train. loss 1.086882e-02. error 1.39%. misses: 100
# eval: split test . loss 3.340305e-02. error 4.98%. misses: 99
# 12
# eval: split train. loss 1.277909e-02. error 1.65%. misses: 119
# eval: split test . loss 3.667589e-02. error 5.63%. misses: 112
# 13
# eval: split train. loss 9.579558e-03. error 1.21%. misses: 88
# eval: split test . loss 3.144594e-02. error 4.73%. misses: 94
# 14
# eval: split train. loss 9.208068e-03. error 1.12%. misses: 82
# eval: split test . loss 3.167238e-02. error 4.48%. misses: 89
# 15
# eval: split train. loss 8.506446e-03. error 1.06%. misses: 76
# eval: split test . loss 3.203600e-02. error 5.03%. misses: 100
# 16
# eval: split train. loss 7.841430e-03. error 1.01%. misses: 74
# eval: split test . loss 3.324178e-02. error 5.23%. misses: 104
# 17
# eval: split train. loss 8.090755e-03. error 1.03%. misses: 74
# eval: split test . loss 3.198257e-02. error 4.63%. misses: 92
# 18
# eval: split train. loss 6.493098e-03. error 0.88%. misses: 63
# eval: split test . loss 3.027189e-02. error 4.73%. misses: 94
# 19
# eval: split train. loss 6.832427e-03. error 0.88%. misses: 63
# eval: split test . loss 3.176200e-02. error 4.68%. misses: 94
# 20
# eval: split train. loss 5.495814e-03. error 0.75%. misses: 54
# eval: split test . loss 3.014830e-02. error 4.78%. misses: 95
# 21
# eval: split train. loss 4.931898e-03. error 0.69%. misses: 50
# eval: split test . loss 2.931301e-02. error 4.24%. misses: 84
# 22
# eval: split train. loss 4.346177e-03. error 0.63%. misses: 46
# eval: split test . loss 2.864180e-02. error 4.38%. misses: 87
# 23
# eval: split train. loss 3.913016e-03. error 0.60%. misses: 44
# eval: split test . loss 2.859631e-02. error 4.24%. misses: 84

# %% [markdown]
# Our error performance is slightly better than reported in the original 1989 paper, but we don't expect to get exactly the same numerical results - we don't have exactly the same data, or random initial weights, and some other details of model training are also not exactly identical.

# %% [markdown]
# In 1989, this model took about 3 days to train on a SUN-4/260 workstation. Today, on a Google Colab hosted CPU runtime (i.e. a VM with 2 Intel(R) Xeon(R) CPUs @ 2.20GHz), it took about 7 minutes.

# %% [markdown]
# ### Visualize misclassified samples for original model

# %%
# The following code is adapted from "vis.ipynb" in the repository.

model.eval()

def grid_mistakes(X, Y):

    plt.figure(figsize=(14, 4))
    ishow, nshow = 0, 14
    for ix in range(X.size(0)):
        x, y = X[[ix]], Y[[ix]]
        yhat = model(x)
        yi = y.argmax()
        yhati = yhat.argmax()
        if yi != yhati:
            plt.subplot(2, 7, ishow+1)
            plt.imshow(x[0,0], cmap='gray')
            plt.title(f'gt={yi}, pred={yhati}')
            plt.axis('off')
            ishow += 1
            if ishow >= nshow:
                break

# %%
# The following code is adapted from "vis.ipynb" in the repository.

grid_mistakes(Xtr, Ytr) # training set mistakes

# %%
# The following code is adapted from "vis.ipynb" in the repository.

grid_mistakes(Xte, Yte) # test set mistakes

# %% [markdown]
# ### Model with updated loss function

# %% [markdown]
# The 1989-era model had a slightly strange (by our "modern" standard) output layer, for a multi-class classification problem -
#
# * there is a tanh activation on the output units, which maps the output for each of the 10 outputs to the range -1 to 1.
# * and then there is a mean squared error loss function on the outputs.
#
# We will "update" the model by removing the tanh activation on the output units, and then using the typical (for a classification problem) [cross entropy loss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss).
#
# I also noticed that when I ran this modified model, the loss seemed to "blow up" suggesting a too-high learning rate - so I reduced the learning rate from 0.03 to 0.01.

# %%
class ModernLossNet(nn.Module):

    def __init__(self):
        super().__init__()

        # initialization as described in the paper to my best ability, but it doesn't look right...
        winit = lambda fan_in, *shape: (torch.rand(*shape) - 0.5) * 2 * 2.4 / fan_in**0.5
        macs = 0 # keep track of MACs (multiply accumulates)
        acts = 0 # keep track of number of activations

        # H1 layer parameters and their initialization
        self.H1w = nn.Parameter(winit(5*5*1, 12, 1, 5, 5))
        self.H1b = nn.Parameter(torch.zeros(12, 8, 8)) # presumably init to zero for biases
        assert self.H1w.nelement() + self.H1b.nelement() == 1068
        macs += (5*5*1) * (8*8) * 12
        acts += (8*8) * 12

        # H2 layer parameters and their initialization
        """
        H2 neurons all connect to only 8 of the 12 input planes, with an unspecified pattern
        I am going to assume the most sensible block pattern where 4 planes at a time connect
        to differently overlapping groups of 8/12 input planes. We will implement this with 3
        separate convolutions that we concatenate the results of.
        """
        self.H2w = nn.Parameter(winit(5*5*8, 12, 8, 5, 5))
        self.H2b = nn.Parameter(torch.zeros(12, 4, 4)) # presumably init to zero for biases
        assert self.H2w.nelement() + self.H2b.nelement() == 2592
        macs += (5*5*8) * (4*4) * 12
        acts += (4*4) * 12

        # H3 is a fully connected layer
        self.H3w = nn.Parameter(winit(4*4*12, 4*4*12, 30))
        self.H3b = nn.Parameter(torch.zeros(30))
        assert self.H3w.nelement() + self.H3b.nelement() == 5790
        macs += (4*4*12) * 30
        acts += 30

        # output layer is also fully connected layer
        self.outw = nn.Parameter(winit(30, 30, 10))
        self.outb = nn.Parameter(-torch.ones(10)) # 9/10 targets are -1, so makes sense to init slightly towards it
        assert self.outw.nelement() + self.outb.nelement() == 310
        macs += 30 * 10
        acts += 10

        self.macs = macs
        self.acts = acts

    def forward(self, x):

        # x has shape (1, 1, 16, 16)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        x = F.conv2d(x, self.H1w, stride=2) + self.H1b
        x = torch.tanh(x)

        # x is now shape (1, 12, 8, 8)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        slice1 = F.conv2d(x[:, 0:8], self.H2w[0:4], stride=2) # first 4 planes look at first 8 input planes
        slice2 = F.conv2d(x[:, 4:12], self.H2w[4:8], stride=2) # next 4 planes look at last 8 input planes
        slice3 = F.conv2d(torch.cat((x[:, 0:4], x[:, 8:12]), dim=1), self.H2w[8:12], stride=2) # last 4 planes are cross
        x = torch.cat((slice1, slice2, slice3), dim=1) + self.H2b
        x = torch.tanh(x)

        # x is now shape (1, 12, 4, 4)
        x = x.flatten(start_dim=1) # (1, 12*4*4)
        x = x @ self.H3w + self.H3b
        x = torch.tanh(x)

        # x is now shape (1, 30)
        x = x @ self.outw + self.outb
        # Note: we deleted the tanh activation here!

         # x is finally shape (1, 10)
        return x

# %%
# Note: with the original learning rate, the SGD did not seem to learn well
# so I changed it to a smaller learning rate
learning_rate = 0.01

# init rng
torch.manual_seed(1337)
np.random.seed(1337)
torch.use_deterministic_algorithms(True)

# init a model
model = ModernLossNet()
print("model stats:")
print("# params:      ", sum(p.numel() for p in model.parameters())) # in paper total is 9,760
print("# MACs:        ", model.macs)
print("# activations: ", model.acts)

# init data
Xtr, Ytr = torch.load('train1989.pt')
Xte, Yte = torch.load('test1989.pt')

# init optimizer
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

def eval_split(split):
    # eval the full train/test set, batched implementation for efficiency
    model.eval()
    X, Y = (Xtr, Ytr) if split == 'train' else (Xte, Yte)
    Yhat = model(X)
    # Note: the updated loss function!
    loss = F.cross_entropy(Yhat, Y.argmax(dim=1))
    err = torch.mean((Y.argmax(dim=1) != Yhat.argmax(dim=1)).float())
    print(f"eval: split {split:5s}. loss {loss.item():e}. error {err.item()*100:.2f}%. misses: {int(err.item()*Y.size(0))}")

# train
for pass_num in range(23):

    # perform one epoch of training
    model.train()
    for step_num in range(Xtr.size(0)):

        # fetch a single example into a batch of 1
        x, y = Xtr[[step_num]], Ytr[[step_num]]

        # forward the model and the loss
        yhat = model(x)
        loss = F.cross_entropy(yhat, y.argmax(dim=1))
        # Note: the updated loss function!

        # calculate the gradient and update the parameters
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # after epoch epoch evaluate the train and test error / metrics
    print(pass_num + 1)
    eval_split('train')
    eval_split('test')

# save final model to file
torch.save(model.state_dict(), 'crossentropy_model.pt')
# Out:
# model stats:
# # params:       9760
# # MACs:         63660
# # activations:  1000
# <ipython-input-11-b3150767bf30>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr, Ytr = torch.load('train1989.pt')
# <ipython-input-11-b3150767bf30>:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte, Yte = torch.load('test1989.pt')
# 1
# eval: split train. loss 2.547413e-01. error 7.57%. misses: 552
# eval: split test . loss 2.883562e-01. error 8.67%. misses: 174
# 2
# eval: split train. loss 1.863158e-01. error 5.76%. misses: 419
# eval: split test . loss 2.397469e-01. error 7.42%. misses: 149
# 3
# eval: split train. loss 1.586120e-01. error 4.58%. misses: 333
# eval: split test . loss 2.223437e-01. error 6.88%. misses: 138
# 4
# eval: split train. loss 1.313847e-01. error 4.11%. misses: 299
# eval: split test . loss 2.194775e-01. error 6.63%. misses: 133
# 5
# eval: split train. loss 1.175028e-01. error 3.79%. misses: 276
# eval: split test . loss 2.284842e-01. error 6.33%. misses: 127
# 6
# eval: split train. loss 9.085781e-02. error 2.72%. misses: 197
# eval: split test . loss 2.107824e-01. error 6.38%. misses: 128
# 7
# eval: split train. loss 7.923040e-02. error 2.41%. misses: 176
# eval: split test . loss 2.086746e-01. error 5.53%. misses: 110
# 8
# eval: split train. loss 6.923635e-02. error 2.06%. misses: 149
# eval: split test . loss 2.043286e-01. error 5.93%. misses: 119
# 9
# eval: split train. loss 6.335890e-02. error 1.85%. misses: 134
# eval: split test . loss 2.065896e-01. error 5.88%. misses: 117
# 10
# eval: split train. loss 3.883694e-02. error 1.07%. misses: 78
# eval: split test . loss 1.898874e-01. error 5.38%. misses: 107
# 11
# eval: split train. loss 2.528628e-02. error 0.69%. misses: 50
# eval: split test . loss 1.883266e-01. error 5.13%. misses: 102
# 12
# eval: split train. loss 2.663554e-02. error 0.69%. misses: 50
# eval: split test . loss 1.959621e-01. error 4.98%. misses: 99
# 13
# eval: split train. loss 2.121301e-02. error 0.51%. misses: 37
# eval: split test . loss 1.944022e-01. error 5.18%. misses: 104
# 14
# eval: split train. loss 1.438397e-02. error 0.27%. misses: 20
# eval: split test . loss 1.977925e-01. error 4.83%. misses: 97
# 15
# eval: split train. loss 1.204782e-02. error 0.21%. misses: 14
# eval: split test . loss 1.966737e-01. error 4.83%. misses: 97
# 16
# eval: split train. loss 8.232183e-03. error 0.12%. misses: 8
# eval: split test . loss 1.959859e-01. error 4.58%. misses: 92
# 17
# eval: split train. loss 6.691971e-03. error 0.07%. misses: 5
# eval: split test . loss 1.973889e-01. error 4.68%. misses: 94
# 18
# eval: split train. loss 5.535982e-03. error 0.05%. misses: 3
# eval: split test . loss 1.978186e-01. error 4.58%. misses: 92
# 19
# eval: split train. loss 4.703921e-03. error 0.04%. misses: 3
# eval: split test . loss 1.983938e-01. error 4.63%. misses: 92
# 20
# eval: split train. loss 4.066921e-03. error 0.03%. misses: 1
# eval: split test . loss 1.989465e-01. error 4.48%. misses: 89
# 21
# eval: split train. loss 3.567336e-03. error 0.01%. misses: 0
# eval: split test . loss 1.994791e-01. error 4.48%. misses: 89
# 22
# eval: split train. loss 3.167902e-03. error 0.01%. misses: 0
# eval: split test . loss 2.000051e-01. error 4.58%. misses: 92
# 23
# eval: split train. loss 2.843769e-03. error 0.00%. misses: 0
# eval: split test . loss 2.005355e-01. error 4.58%. misses: 92

# %% [markdown]
# The test performance is similar, maybe a little worse - since I reduced the learning rate, I may need to increase the number of passes to compensate.
#
# But, we are now seeing zero error on the training set. We may be overfitting.
#
# Fortunately, we have some "tricks" for improving the performance of deep neural networks! We can try -
#
# * a more modern optimizer (i.e. improve over the stochastic gradient descent with fixed learning rate)
# * data augmentation
# * a regularization technique, like dropout
#
# and see if they improve our performance, while still keeping the basic model - number of layers, number of units, size of each convolutional filter - the same.

# %% [markdown]
# ### Training with a better optimizer

# %% [markdown]
# The original model is trained using stochastic gradient descent on a single sample at a time, with a fixed learning rate.
#
# To see if a more sophisticated optimizer will help, we will try to train the same model with a version of the Adam optimizer. Adam is a combination of two gradient descent "variations" we have discussed previously:
#
# * Momentum - uses a velocity vector that accumulates gradient of past steps.
# * RMSProp - normalizes parameter update using per-parameter EWMA of square of gradient.
#
# and it is often used as a starting point when training deep neural networks.
#
# We are also going to "decay" the learning rate as we iterate over the number of epochs.
#
# And, we will also double the number of training epochs from 23 to 46.

# %%
# The following code is adapted from "modern.py" in the repository.

# Note: different initial learning rate
learning_rate = 3e-4

# init rng
torch.manual_seed(1337)
np.random.seed(1337)
torch.use_deterministic_algorithms(True)

# init a model
model = ModernLossNet()
print("model stats:")
print("# params:      ", sum(p.numel() for p in model.parameters())) # in paper total is 9,760
print("# MACs:        ", model.macs)
print("# activations: ", model.acts)

# init data
Xtr, Ytr = torch.load('train1989.pt')
Xte, Yte = torch.load('test1989.pt')

# init optimizer
# Note: use the the AdamW optimizer
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

def eval_split(split):
    # eval the full train/test set, batched implementation for efficiency
    model.eval()
    X, Y = (Xtr, Ytr) if split == 'train' else (Xte, Yte)
    Yhat = model(X)
    loss = F.cross_entropy(Yhat, Y.argmax(dim=1))
    err = torch.mean((Y.argmax(dim=1) != Yhat.argmax(dim=1)).float())
    print(f"eval: split {split:5s}. loss {loss.item():e}. error {err.item()*100:.2f}%. misses: {int(err.item()*Y.size(0))}")

# Note: increase number of training passes
for pass_num in range(46):

    # Note: also implement learning rate decay
    alpha = pass_num / 45
    for g in optimizer.param_groups:
        g['lr'] = (1 - alpha) * learning_rate + alpha * (learning_rate / 3)

    # perform one epoch of training
    model.train()
    for step_num in range(Xtr.size(0)):

        # fetch a single example into a batch of 1
        x, y = Xtr[[step_num]], Ytr[[step_num]]

        # forward the model and the loss
        yhat = model(x)
        loss = F.cross_entropy(yhat, y.argmax(dim=1))

        # calculate the gradient and update the parameters
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # after epoch epoch evaluate the train and test error / metrics
    print(pass_num + 1)
    eval_split('train')
    eval_split('test')

# save final model to file
torch.save(model.state_dict(), 'adam_model.pt')
# Out:
# model stats:
# # params:       9760
# # MACs:         63660
# # activations:  1000
# <ipython-input-12-d4cf4ab35e3c>:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr, Ytr = torch.load('train1989.pt')
# <ipython-input-12-d4cf4ab35e3c>:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte, Yte = torch.load('test1989.pt')
# 1
# eval: split train. loss 3.400726e-01. error 9.30%. misses: 678
# eval: split test . loss 3.691344e-01. error 10.31%. misses: 206
# 2
# eval: split train. loss 2.354495e-01. error 6.61%. misses: 482
# eval: split test . loss 2.723993e-01. error 7.77%. misses: 155
# 3
# eval: split train. loss 1.842819e-01. error 5.12%. misses: 373
# eval: split test . loss 2.294076e-01. error 6.73%. misses: 134
# 4
# eval: split train. loss 1.493117e-01. error 4.28%. misses: 312
# eval: split test . loss 2.028433e-01. error 6.03%. misses: 120
# 5
# eval: split train. loss 1.249706e-01. error 3.28%. misses: 239
# eval: split test . loss 1.848712e-01. error 5.58%. misses: 112
# 6
# eval: split train. loss 1.059840e-01. error 2.89%. misses: 211
# eval: split test . loss 1.713369e-01. error 5.23%. misses: 104
# 7
# eval: split train. loss 8.992923e-02. error 2.46%. misses: 178
# eval: split test . loss 1.604009e-01. error 5.03%. misses: 100
# 8
# eval: split train. loss 7.654223e-02. error 2.00%. misses: 145
# eval: split test . loss 1.520333e-01. error 4.68%. misses: 94
# 9
# eval: split train. loss 6.583454e-02. error 1.67%. misses: 122
# eval: split test . loss 1.461771e-01. error 4.53%. misses: 91
# 10
# eval: split train. loss 5.761415e-02. error 1.45%. misses: 106
# eval: split test . loss 1.422049e-01. error 4.29%. misses: 86
# 11
# eval: split train. loss 5.055852e-02. error 1.23%. misses: 90
# eval: split test . loss 1.384851e-01. error 4.29%. misses: 86
# 12
# eval: split train. loss 4.438356e-02. error 1.12%. misses: 82
# eval: split test . loss 1.345565e-01. error 4.09%. misses: 82
# 13
# eval: split train. loss 3.957435e-02. error 0.96%. misses: 69
# eval: split test . loss 1.313436e-01. error 3.84%. misses: 77
# 14
# eval: split train. loss 3.562195e-02. error 0.82%. misses: 59
# eval: split test . loss 1.290146e-01. error 3.89%. misses: 77
# 15
# eval: split train. loss 3.229970e-02. error 0.78%. misses: 57
# eval: split test . loss 1.280172e-01. error 3.84%. misses: 77
# 16
# eval: split train. loss 2.949240e-02. error 0.66%. misses: 48
# eval: split test . loss 1.287774e-01. error 4.04%. misses: 81
# 17
# eval: split train. loss 2.647738e-02. error 0.62%. misses: 45
# eval: split test . loss 1.304962e-01. error 4.09%. misses: 82
# 18
# eval: split train. loss 2.301653e-02. error 0.53%. misses: 39
# eval: split test . loss 1.320908e-01. error 4.19%. misses: 84
# 19
# eval: split train. loss 1.977339e-02. error 0.45%. misses: 32
# eval: split test . loss 1.338921e-01. error 4.19%. misses: 84
# 20
# eval: split train. loss 1.778473e-02. error 0.43%. misses: 30
# eval: split test . loss 1.350195e-01. error 4.29%. misses: 86
# 21
# eval: split train. loss 1.702846e-02. error 0.41%. misses: 29
# eval: split test . loss 1.380503e-01. error 4.29%. misses: 86
# 22
# eval: split train. loss 1.256238e-02. error 0.26%. misses: 19
# eval: split test . loss 1.324348e-01. error 3.89%. misses: 77
# 23
# eval: split train. loss 1.061959e-02. error 0.18%. misses: 13
# eval: split test . loss 1.311071e-01. error 3.99%. misses: 79
# 24
# eval: split train. loss 1.446019e-02. error 0.30%. misses: 22
# eval: split test . loss 1.473677e-01. error 4.38%. misses: 87
# 25
# eval: split train. loss 1.219019e-02. error 0.23%. misses: 16
# eval: split test . loss 1.379658e-01. error 4.14%. misses: 82
# 26
# eval: split train. loss 9.630823e-03. error 0.19%. misses: 13
# eval: split test . loss 1.460100e-01. error 3.84%. misses: 77
# 27
# eval: split train. loss 8.965677e-03. error 0.14%. misses: 10
# eval: split test . loss 1.451758e-01. error 4.14%. misses: 82
# 28
# eval: split train. loss 7.781895e-03. error 0.18%. misses: 13
# eval: split test . loss 1.361227e-01. error 3.94%. misses: 79
# 29
# eval: split train. loss 9.695320e-03. error 0.26%. misses: 19
# eval: split test . loss 1.415954e-01. error 4.04%. misses: 81
# 30
# eval: split train. loss 1.258833e-02. error 0.36%. misses: 26
# eval: split test . loss 1.684960e-01. error 4.43%. misses: 89
# 31
# eval: split train. loss 7.382781e-03. error 0.18%. misses: 13
# eval: split test . loss 1.528282e-01. error 3.99%. misses: 79
# 32
# eval: split train. loss 7.347674e-03. error 0.16%. misses: 12
# eval: split test . loss 1.514108e-01. error 3.89%. misses: 77
# 33
# eval: split train. loss 3.667826e-03. error 0.05%. misses: 3
# eval: split test . loss 1.439678e-01. error 3.89%. misses: 77
# 34
# eval: split train. loss 4.571799e-03. error 0.11%. misses: 7
# eval: split test . loss 1.444231e-01. error 3.94%. misses: 79
# 35
# eval: split train. loss 3.124332e-03. error 0.01%. misses: 0
# eval: split test . loss 1.502858e-01. error 3.74%. misses: 74
# 36
# eval: split train. loss 2.852841e-03. error 0.04%. misses: 3
# eval: split test . loss 1.436194e-01. error 3.49%. misses: 69
# 37
# eval: split train. loss 2.661057e-03. error 0.01%. misses: 0
# eval: split test . loss 1.523224e-01. error 3.54%. misses: 71
# 38
# eval: split train. loss 2.051077e-03. error 0.04%. misses: 3
# eval: split test . loss 1.526967e-01. error 3.69%. misses: 74
# 39
# eval: split train. loss 1.941941e-03. error 0.03%. misses: 1
# eval: split test . loss 1.520318e-01. error 3.59%. misses: 72
# 40
# eval: split train. loss 2.387499e-03. error 0.04%. misses: 3
# eval: split test . loss 1.672167e-01. error 3.84%. misses: 77
# 41
# eval: split train. loss 1.963411e-03. error 0.03%. misses: 1
# eval: split test . loss 1.562935e-01. error 3.64%. misses: 72
# 42
# eval: split train. loss 1.437521e-03. error 0.01%. misses: 0
# eval: split test . loss 1.617592e-01. error 3.59%. misses: 72
# 43
# eval: split train. loss 1.359510e-03. error 0.01%. misses: 0
# eval: split test . loss 1.630140e-01. error 3.59%. misses: 72
# 44
# eval: split train. loss 8.305132e-04. error 0.00%. misses: 0
# eval: split test . loss 1.608218e-01. error 3.84%. misses: 77
# 45
# eval: split train. loss 7.954442e-04. error 0.00%. misses: 0
# eval: split test . loss 1.623634e-01. error 3.59%. misses: 72
# 46
# eval: split train. loss 7.000595e-04. error 0.00%. misses: 0
# eval: split test . loss 1.666930e-01. error 3.59%. misses: 72

# %% [markdown]
# We seem to have improved the test performance - it is now below 4% error. We are still achieving 0 error on the training set, so we remain concerned about potential overfitting.

# %% [markdown]
# ### Training with data augmentation

# %% [markdown]
# To combat potential overfitting, we can add some basic data augmentation. When we load a training sample, we will randomly shift it by up to one pixel in the vertical and/or horizontal directions.
#
# We also increase the number of passes again to 60, since data augmentation (1) increases the effective "size" of the training set, and (2) also adds some "noise" to the training process.

# %%
# The following code is adapted from "modern.py" in the repository.

class ModernDataAugNet(nn.Module):

    def __init__(self):
        super().__init__()

        # initialization as described in the paper to my best ability, but it doesn't look right...
        winit = lambda fan_in, *shape: (torch.rand(*shape) - 0.5) * 2 * 2.4 / fan_in**0.5
        macs = 0 # keep track of MACs (multiply accumulates)
        acts = 0 # keep track of number of activations

        # H1 layer parameters and their initialization
        self.H1w = nn.Parameter(winit(5*5*1, 12, 1, 5, 5))
        self.H1b = nn.Parameter(torch.zeros(12, 8, 8)) # presumably init to zero for biases
        macs += (5*5*1) * (8*8) * 12
        acts += (8*8) * 12

        # H2 layer parameters and their initialization
        """
        H2 neurons all connect to only 8 of the 12 input planes, with an unspecified pattern
        I am going to assume the most sensible block pattern where 4 planes at a time connect
        to differently overlapping groups of 8/12 input planes. We will implement this with 3
        separate convolutions that we concatenate the results of.
        """
        self.H2w = nn.Parameter(winit(5*5*8, 12, 8, 5, 5))
        self.H2b = nn.Parameter(torch.zeros(12, 4, 4)) # presumably init to zero for biases
        macs += (5*5*8) * (4*4) * 12
        acts += (4*4) * 12

        # H3 is a fully connected layer
        self.H3w = nn.Parameter(winit(4*4*12, 4*4*12, 30))
        self.H3b = nn.Parameter(torch.zeros(30))
        macs += (4*4*12) * 30
        acts += 30

        # output layer is also fully connected layer
        self.outw = nn.Parameter(winit(30, 30, 10))
        self.outb = nn.Parameter(torch.zeros(10))
        macs += 30 * 10
        acts += 10

        self.macs = macs
        self.acts = acts

    def forward(self, x):

        # Note: basic data augmentation by 1 pixel along x/y directions
        if self.training:
            shift_x, shift_y = np.random.randint(-1, 2, size=2)
            x = torch.roll(x, (shift_x, shift_y), (2, 3))

        # x has shape (1, 1, 16, 16)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        x = F.conv2d(x, self.H1w, stride=2) + self.H1b
        x = torch.tanh(x)

        # x is now shape (1, 12, 8, 8)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        slice1 = F.conv2d(x[:, 0:8], self.H2w[0:4], stride=2) # first 4 planes look at first 8 input planes
        slice2 = F.conv2d(x[:, 4:12], self.H2w[4:8], stride=2) # next 4 planes look at last 8 input planes
        slice3 = F.conv2d(torch.cat((x[:, 0:4], x[:, 8:12]), dim=1), self.H2w[8:12], stride=2) # last 4 planes are cross
        x = torch.cat((slice1, slice2, slice3), dim=1) + self.H2b
        x = torch.tanh(x)

        # x is now shape (1, 12, 4, 4)
        x = x.flatten(start_dim=1) # (1, 12*4*4)
        x = x @ self.H3w + self.H3b
        x = torch.tanh(x)

        # x is now shape (1, 30)
        x = x @ self.outw + self.outb

         # x is finally shape (1, 10)
        return x

# %%
# The following code is adapted from "modern.py" in the repository.

learning_rate = 3e-4

# init rng
torch.manual_seed(1337)
np.random.seed(1337)
torch.use_deterministic_algorithms(True)

# init a model
model = ModernDataAugNet()
print("model stats:")
print("# params:      ", sum(p.numel() for p in model.parameters())) # in paper total is 9,760
print("# MACs:        ", model.macs)
print("# activations: ", model.acts)

# init data
Xtr, Ytr = torch.load('train1989.pt')
Xte, Yte = torch.load('test1989.pt')

# init optimizer
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

def eval_split(split):
    # eval the full train/test set, batched implementation for efficiency
    model.eval()
    X, Y = (Xtr, Ytr) if split == 'train' else (Xte, Yte)
    Yhat = model(X)
    loss = F.cross_entropy(Yhat, Y.argmax(dim=1))
    err = torch.mean((Y.argmax(dim=1) != Yhat.argmax(dim=1)).float())
    print(f"eval: split {split:5s}. loss {loss.item():e}. error {err.item()*100:.2f}%. misses: {int(err.item()*Y.size(0))}")

# train
for pass_num in range(60):

    # learning rate decay
    alpha = pass_num / 79
    for g in optimizer.param_groups:
        g['lr'] = (1 - alpha) * learning_rate + alpha * (learning_rate / 3)

    # perform one epoch of training
    model.train()
    for step_num in range(Xtr.size(0)):

        # fetch a single example into a batch of 1
        x, y = Xtr[[step_num]], Ytr[[step_num]]

        # forward the model and the loss
        yhat = model(x)
        loss = F.cross_entropy(yhat, y.argmax(dim=1))

        # calculate the gradient and update the parameters
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # after epoch epoch evaluate the train and test error / metrics
    print(pass_num + 1)
    eval_split('train')
    eval_split('test')

# save final model to file
torch.save(model.state_dict(), 'dataug_model.pt')
# Out:
# model stats:
# # params:       9760
# # MACs:         63660
# # activations:  1000
# <ipython-input-14-cf587ad9440c>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr, Ytr = torch.load('train1989.pt')
# <ipython-input-14-cf587ad9440c>:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte, Yte = torch.load('test1989.pt')
# 1
# eval: split train. loss 5.288423e-01. error 13.48%. misses: 982
# eval: split test . loss 5.376811e-01. error 13.65%. misses: 274
# 2
# eval: split train. loss 3.618094e-01. error 9.74%. misses: 710
# eval: split test . loss 3.622440e-01. error 10.21%. misses: 204
# 3
# eval: split train. loss 2.770010e-01. error 7.78%. misses: 567
# eval: split test . loss 2.691664e-01. error 7.77%. misses: 155
# 4
# eval: split train. loss 2.191166e-01. error 6.32%. misses: 460
# eval: split test . loss 2.131962e-01. error 5.88%. misses: 117
# 5
# eval: split train. loss 1.949559e-01. error 5.71%. misses: 416
# eval: split test . loss 2.028036e-01. error 6.13%. misses: 122
# 6
# eval: split train. loss 1.760965e-01. error 5.09%. misses: 371
# eval: split test . loss 1.767326e-01. error 5.28%. misses: 105
# 7
# eval: split train. loss 1.579356e-01. error 4.69%. misses: 341
# eval: split test . loss 1.632146e-01. error 5.08%. misses: 102
# 8
# eval: split train. loss 1.546873e-01. error 4.65%. misses: 339
# eval: split test . loss 1.586834e-01. error 5.38%. misses: 107
# 9
# eval: split train. loss 1.436165e-01. error 4.13%. misses: 301
# eval: split test . loss 1.457766e-01. error 4.19%. misses: 84
# 10
# eval: split train. loss 1.445486e-01. error 4.10%. misses: 298
# eval: split test . loss 1.534751e-01. error 4.78%. misses: 95
# 11
# eval: split train. loss 1.282287e-01. error 3.80%. misses: 277
# eval: split test . loss 1.302226e-01. error 3.54%. misses: 71
# 12
# eval: split train. loss 1.162532e-01. error 3.46%. misses: 252
# eval: split test . loss 1.203833e-01. error 3.69%. misses: 74
# 13
# eval: split train. loss 1.195214e-01. error 3.39%. misses: 247
# eval: split test . loss 1.223768e-01. error 3.79%. misses: 76
# 14
# eval: split train. loss 1.282652e-01. error 3.80%. misses: 277
# eval: split test . loss 1.363555e-01. error 4.29%. misses: 86
# 15
# eval: split train. loss 1.155965e-01. error 3.48%. misses: 253
# eval: split test . loss 1.240505e-01. error 4.04%. misses: 81
# 16
# eval: split train. loss 1.248293e-01. error 3.77%. misses: 274
# eval: split test . loss 1.281882e-01. error 3.89%. misses: 77
# 17
# eval: split train. loss 1.087283e-01. error 3.26%. misses: 237
# eval: split test . loss 1.133182e-01. error 4.04%. misses: 81
# 18
# eval: split train. loss 1.060524e-01. error 3.31%. misses: 241
# eval: split test . loss 1.095671e-01. error 3.59%. misses: 72
# 19
# eval: split train. loss 1.018783e-01. error 2.77%. misses: 201
# eval: split test . loss 1.119648e-01. error 3.54%. misses: 71
# 20
# eval: split train. loss 1.059441e-01. error 3.15%. misses: 229
# eval: split test . loss 1.105625e-01. error 3.24%. misses: 64
# 21
# eval: split train. loss 9.508308e-02. error 3.02%. misses: 219
# eval: split test . loss 1.018330e-01. error 3.09%. misses: 62
# 22
# eval: split train. loss 9.896741e-02. error 3.17%. misses: 231
# eval: split test . loss 1.078555e-01. error 3.49%. misses: 69
# 23
# eval: split train. loss 9.296913e-02. error 2.73%. misses: 199
# eval: split test . loss 9.956332e-02. error 2.89%. misses: 57
# 24
# eval: split train. loss 9.037109e-02. error 2.72%. misses: 197
# eval: split test . loss 9.971094e-02. error 3.64%. misses: 72
# 25
# eval: split train. loss 9.541636e-02. error 2.96%. misses: 216
# eval: split test . loss 9.714393e-02. error 2.99%. misses: 60
# 26
# eval: split train. loss 8.974429e-02. error 2.85%. misses: 208
# eval: split test . loss 9.714549e-02. error 3.29%. misses: 66
# 27
# eval: split train. loss 9.691904e-02. error 3.13%. misses: 228
# eval: split test . loss 1.062865e-01. error 3.54%. misses: 71
# 28
# eval: split train. loss 9.209245e-02. error 2.77%. misses: 201
# eval: split test . loss 9.495605e-02. error 3.09%. misses: 62
# 29
# eval: split train. loss 9.879288e-02. error 3.06%. misses: 223
# eval: split test . loss 1.049160e-01. error 3.54%. misses: 71
# 30
# eval: split train. loss 8.013646e-02. error 2.44%. misses: 177
# eval: split test . loss 8.712281e-02. error 2.79%. misses: 56
# 31
# eval: split train. loss 8.554639e-02. error 2.66%. misses: 193
# eval: split test . loss 9.827577e-02. error 3.54%. misses: 71
# 32
# eval: split train. loss 8.692322e-02. error 2.73%. misses: 199
# eval: split test . loss 8.911611e-02. error 3.09%. misses: 62
# 33
# eval: split train. loss 7.489815e-02. error 2.26%. misses: 165
# eval: split test . loss 7.961068e-02. error 2.59%. misses: 52
# 34
# eval: split train. loss 7.969452e-02. error 2.41%. misses: 176
# eval: split test . loss 9.192310e-02. error 3.09%. misses: 62
# 35
# eval: split train. loss 8.791099e-02. error 2.74%. misses: 200
# eval: split test . loss 9.361410e-02. error 3.44%. misses: 69
# 36
# eval: split train. loss 8.169262e-02. error 2.69%. misses: 196
# eval: split test . loss 9.087690e-02. error 3.14%. misses: 62
# 37
# eval: split train. loss 8.223048e-02. error 2.70%. misses: 196
# eval: split test . loss 8.681617e-02. error 2.94%. misses: 58
# 38
# eval: split train. loss 8.433951e-02. error 2.77%. misses: 201
# eval: split test . loss 8.475800e-02. error 2.74%. misses: 54
# 39
# eval: split train. loss 7.886914e-02. error 2.48%. misses: 181
# eval: split test . loss 9.483948e-02. error 3.14%. misses: 62
# 40
# eval: split train. loss 8.299026e-02. error 2.55%. misses: 185
# eval: split test . loss 9.049775e-02. error 2.89%. misses: 57
# 41
# eval: split train. loss 8.681893e-02. error 2.73%. misses: 199
# eval: split test . loss 9.675442e-02. error 3.29%. misses: 66
# 42
# eval: split train. loss 6.955156e-02. error 2.14%. misses: 156
# eval: split test . loss 8.768851e-02. error 2.79%. misses: 56
# 43
# eval: split train. loss 8.520127e-02. error 2.66%. misses: 193
# eval: split test . loss 9.470096e-02. error 2.99%. misses: 60
# 44
# eval: split train. loss 7.159816e-02. error 2.18%. misses: 158
# eval: split test . loss 8.304396e-02. error 2.59%. misses: 52
# 45
# eval: split train. loss 6.552259e-02. error 2.17%. misses: 157
# eval: split test . loss 6.739183e-02. error 2.34%. misses: 47
# 46
# eval: split train. loss 7.286438e-02. error 2.26%. misses: 165
# eval: split test . loss 8.435990e-02. error 2.64%. misses: 52
# 47
# eval: split train. loss 7.106229e-02. error 2.08%. misses: 152
# eval: split test . loss 8.492769e-02. error 2.84%. misses: 57
# 48
# eval: split train. loss 7.073155e-02. error 2.00%. misses: 145
# eval: split test . loss 8.464669e-02. error 2.79%. misses: 56
# 49
# eval: split train. loss 6.227525e-02. error 2.00%. misses: 145
# eval: split test . loss 7.101504e-02. error 2.19%. misses: 43
# 50
# eval: split train. loss 7.140755e-02. error 2.28%. misses: 165
# eval: split test . loss 7.367762e-02. error 2.24%. misses: 44
# 51
# eval: split train. loss 7.048889e-02. error 2.39%. misses: 173
# eval: split test . loss 7.467532e-02. error 2.24%. misses: 44
# 52
# eval: split train. loss 6.115722e-02. error 1.78%. misses: 130
# eval: split test . loss 7.857244e-02. error 2.59%. misses: 52
# 53
# eval: split train. loss 6.965934e-02. error 2.24%. misses: 162
# eval: split test . loss 7.686996e-02. error 2.59%. misses: 52
# 54
# eval: split train. loss 6.503516e-02. error 2.07%. misses: 150
# eval: split test . loss 7.360505e-02. error 2.34%. misses: 47
# 55
# eval: split train. loss 5.798615e-02. error 1.84%. misses: 134
# eval: split test . loss 7.086550e-02. error 2.34%. misses: 47
# 56
# eval: split train. loss 6.643338e-02. error 2.15%. misses: 157
# eval: split test . loss 7.341868e-02. error 2.19%. misses: 43
# 57
# eval: split train. loss 6.505818e-02. error 2.04%. misses: 149
# eval: split test . loss 6.975473e-02. error 2.24%. misses: 44
# 58
# eval: split train. loss 6.110305e-02. error 1.87%. misses: 135
# eval: split test . loss 6.950997e-02. error 1.89%. misses: 38
# 59
# eval: split train. loss 6.753769e-02. error 2.13%. misses: 154
# eval: split test . loss 8.551272e-02. error 2.94%. misses: 58
# 60
# eval: split train. loss 6.353485e-02. error 1.89%. misses: 138
# eval: split test . loss 7.454803e-02. error 2.29%. misses: 46

# %% [markdown]
# Data augmentation - used in combination with our other improvements - seems to help a lot! Our test error is now comfortably under 3%.

# %% [markdown]
# ### Model with dropout (and ReLU)

# %% [markdown]
# Another tools to combat overfitting is regularization. To regularize the network, we add a dropout layer with 0.25 probability just before the layer with the largest number of parameters (H3).
#
# Because dropout zeros some activations, it doesn’t make as much sense to use it with tanh activations that map outputs to the range -1 to 1. So, we also change the activations throughout the hidden layers from tanh to ReLU.
#
# Finally, we increase the number of training epochs again to 80, since dropout introduces some more noise in the training process.

# %%
# The following code is adapted from "modern.py" in the repository.

class ModernDropoutNet(nn.Module):

    def __init__(self):
        super().__init__()

        # initialization as described in the paper to my best ability, but it doesn't look right...
        winit = lambda fan_in, *shape: (torch.rand(*shape) - 0.5) * 2 * 2.4 / fan_in**0.5
        macs = 0 # keep track of MACs (multiply accumulates)
        acts = 0 # keep track of number of activations

        # H1 layer parameters and their initialization
        self.H1w = nn.Parameter(winit(5*5*1, 12, 1, 5, 5))
        self.H1b = nn.Parameter(torch.zeros(12, 8, 8)) # presumably init to zero for biases
        macs += (5*5*1) * (8*8) * 12
        acts += (8*8) * 12

        # H2 layer parameters and their initialization
        """
        H2 neurons all connect to only 8 of the 12 input planes, with an unspecified pattern
        I am going to assume the most sensible block pattern where 4 planes at a time connect
        to differently overlapping groups of 8/12 input planes. We will implement this with 3
        separate convolutions that we concatenate the results of.
        """
        self.H2w = nn.Parameter(winit(5*5*8, 12, 8, 5, 5))
        self.H2b = nn.Parameter(torch.zeros(12, 4, 4)) # presumably init to zero for biases
        macs += (5*5*8) * (4*4) * 12
        acts += (4*4) * 12

        # H3 is a fully connected layer
        self.H3w = nn.Parameter(winit(4*4*12, 4*4*12, 30))
        self.H3b = nn.Parameter(torch.zeros(30))
        macs += (4*4*12) * 30
        acts += 30

        # output layer is also fully connected layer
        self.outw = nn.Parameter(winit(30, 30, 10))
        self.outb = nn.Parameter(torch.zeros(10))
        macs += 30 * 10
        acts += 10

        self.macs = macs
        self.acts = acts

    def forward(self, x):

        # poor man's data augmentation by 1 pixel along x/y directions
        if self.training:
            shift_x, shift_y = np.random.randint(-1, 2, size=2)
            x = torch.roll(x, (shift_x, shift_y), (2, 3))

        # x has shape (1, 1, 16, 16)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        x = F.conv2d(x, self.H1w, stride=2) + self.H1b
        x = torch.relu(x) # Note: ReLU activation!

        # x is now shape (1, 12, 8, 8)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        slice1 = F.conv2d(x[:, 0:8], self.H2w[0:4], stride=2) # first 4 planes look at first 8 input planes
        slice2 = F.conv2d(x[:, 4:12], self.H2w[4:8], stride=2) # next 4 planes look at last 8 input planes
        slice3 = F.conv2d(torch.cat((x[:, 0:4], x[:, 8:12]), dim=1), self.H2w[8:12], stride=2) # last 4 planes are cross
        x = torch.cat((slice1, slice2, slice3), dim=1) + self.H2b
        x = torch.relu(x) # Note: ReLU activation!

        # x is now shape (1, 12, 4, 4)
        x = x.flatten(start_dim=1) # (1, 12*4*4)
        x = x @ self.H3w + self.H3b
        x = torch.relu(x) # Note: ReLU activation!
        x = F.dropout(x, p=0.25, training=self.training) # Note: dropout layer!


        # x is now shape (1, 30)
        x = x @ self.outw + self.outb

         # x is finally shape (1, 10)
        return x

# %%
# The following code is adapted from "modern.py" in the repository.

learning_rate = 3e-4

# init rng
torch.manual_seed(1337)
np.random.seed(1337)
torch.use_deterministic_algorithms(True)

# init a model
model = ModernDropoutNet()
print("model stats:")
print("# params:      ", sum(p.numel() for p in model.parameters())) # in paper total is 9,760
print("# MACs:        ", model.macs)
print("# activations: ", model.acts)

# init data
Xtr, Ytr = torch.load('train1989.pt')
Xte, Yte = torch.load('test1989.pt')

# init optimizer
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

def eval_split(split):
    # eval the full train/test set, batched implementation for efficiency
    model.eval()
    X, Y = (Xtr, Ytr) if split == 'train' else (Xte, Yte)
    Yhat = model(X)
    loss = F.cross_entropy(Yhat, Y.argmax(dim=1))
    err = torch.mean((Y.argmax(dim=1) != Yhat.argmax(dim=1)).float())
    print(f"eval: split {split:5s}. loss {loss.item():e}. error {err.item()*100:.2f}%. misses: {int(err.item()*Y.size(0))}")

# train
for pass_num in range(80):

    # learning rate decay
    alpha = pass_num / 79
    for g in optimizer.param_groups:
        g['lr'] = (1 - alpha) * learning_rate + alpha * (learning_rate / 3)

    # perform one epoch of training
    model.train()
    for step_num in range(Xtr.size(0)):

        # fetch a single example into a batch of 1
        x, y = Xtr[[step_num]], Ytr[[step_num]]

        # forward the model and the loss
        yhat = model(x)
        loss = F.cross_entropy(yhat, y.argmax(dim=1))

        # calculate the gradient and update the parameters
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # after epoch epoch evaluate the train and test error / metrics
    print(pass_num + 1)
    eval_split('train')
    eval_split('test')

# save final model to file
torch.save(model.state_dict(), 'dropout_model.pt')
# Out:
# model stats:
# # params:       9760
# # MACs:         63660
# # activations:  1000
# <ipython-input-16-ccffb26cc492>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr, Ytr = torch.load('train1989.pt')
# <ipython-input-16-ccffb26cc492>:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte, Yte = torch.load('test1989.pt')
# 1
# eval: split train. loss 5.223247e-01. error 13.59%. misses: 991
# eval: split test . loss 5.147547e-01. error 13.25%. misses: 266
# 2
# eval: split train. loss 3.238890e-01. error 8.53%. misses: 622
# eval: split test . loss 3.289564e-01. error 8.92%. misses: 179
# 3
# eval: split train. loss 2.514305e-01. error 6.71%. misses: 488
# eval: split test . loss 2.508721e-01. error 6.83%. misses: 137
# 4
# eval: split train. loss 1.951051e-01. error 6.09%. misses: 444
# eval: split test . loss 1.937159e-01. error 5.63%. misses: 112
# 5
# eval: split train. loss 1.840068e-01. error 5.60%. misses: 408
# eval: split test . loss 1.839082e-01. error 5.53%. misses: 110
# 6
# eval: split train. loss 1.675366e-01. error 5.29%. misses: 385
# eval: split test . loss 1.718292e-01. error 5.63%. misses: 112
# 7
# eval: split train. loss 1.384703e-01. error 4.35%. misses: 317
# eval: split test . loss 1.410664e-01. error 4.43%. misses: 89
# 8
# eval: split train. loss 1.329197e-01. error 4.11%. misses: 299
# eval: split test . loss 1.346521e-01. error 4.09%. misses: 82
# 9
# eval: split train. loss 1.263266e-01. error 4.03%. misses: 293
# eval: split test . loss 1.341540e-01. error 4.04%. misses: 81
# 10
# eval: split train. loss 1.126098e-01. error 3.26%. misses: 237
# eval: split test . loss 1.222452e-01. error 3.74%. misses: 74
# 11
# eval: split train. loss 1.161934e-01. error 3.79%. misses: 276
# eval: split test . loss 1.245866e-01. error 3.49%. misses: 69
# 12
# eval: split train. loss 1.070009e-01. error 3.14%. misses: 228
# eval: split test . loss 1.141998e-01. error 3.69%. misses: 74
# 13
# eval: split train. loss 1.074354e-01. error 3.33%. misses: 242
# eval: split test . loss 1.207490e-01. error 3.79%. misses: 76
# 14
# eval: split train. loss 9.967225e-02. error 3.03%. misses: 220
# eval: split test . loss 1.062318e-01. error 3.34%. misses: 66
# 15
# eval: split train. loss 1.018697e-01. error 3.26%. misses: 237
# eval: split test . loss 1.127306e-01. error 3.44%. misses: 69
# 16
# eval: split train. loss 1.219314e-01. error 3.90%. misses: 284
# eval: split test . loss 1.407358e-01. error 4.63%. misses: 92
# 17
# eval: split train. loss 9.049914e-02. error 3.00%. misses: 219
# eval: split test . loss 1.018967e-01. error 3.34%. misses: 66
# 18
# eval: split train. loss 8.456835e-02. error 2.67%. misses: 195
# eval: split test . loss 9.891368e-02. error 3.09%. misses: 62
# 19
# eval: split train. loss 9.319668e-02. error 2.98%. misses: 216
# eval: split test . loss 1.070321e-01. error 3.54%. misses: 71
# 20
# eval: split train. loss 9.257818e-02. error 3.03%. misses: 220
# eval: split test . loss 9.804573e-02. error 2.84%. misses: 57
# 21
# eval: split train. loss 8.947950e-02. error 2.85%. misses: 208
# eval: split test . loss 9.878916e-02. error 3.19%. misses: 64
# 22
# eval: split train. loss 8.134156e-02. error 2.50%. misses: 181
# eval: split test . loss 9.756315e-02. error 2.94%. misses: 58
# 23
# eval: split train. loss 8.750962e-02. error 2.67%. misses: 195
# eval: split test . loss 9.446713e-02. error 2.89%. misses: 57
# 24
# eval: split train. loss 7.855190e-02. error 2.59%. misses: 188
# eval: split test . loss 8.393410e-02. error 2.49%. misses: 49
# 25
# eval: split train. loss 8.398571e-02. error 2.74%. misses: 200
# eval: split test . loss 9.726250e-02. error 3.09%. misses: 62
# 26
# eval: split train. loss 8.431271e-02. error 2.80%. misses: 204
# eval: split test . loss 9.272253e-02. error 2.99%. misses: 60
# 27
# eval: split train. loss 6.907625e-02. error 2.18%. misses: 158
# eval: split test . loss 8.874486e-02. error 2.94%. misses: 58
# 28
# eval: split train. loss 7.740109e-02. error 2.46%. misses: 178
# eval: split test . loss 1.016128e-01. error 3.39%. misses: 67
# 29
# eval: split train. loss 7.038057e-02. error 2.14%. misses: 156
# eval: split test . loss 8.440578e-02. error 2.74%. misses: 54
# 30
# eval: split train. loss 7.063943e-02. error 2.32%. misses: 169
# eval: split test . loss 8.563738e-02. error 2.89%. misses: 57
# 31
# eval: split train. loss 6.579842e-02. error 2.11%. misses: 153
# eval: split test . loss 7.577666e-02. error 2.04%. misses: 41
# 32
# eval: split train. loss 6.881603e-02. error 2.14%. misses: 156
# eval: split test . loss 8.469580e-02. error 2.39%. misses: 47
# 33
# eval: split train. loss 7.501931e-02. error 2.36%. misses: 172
# eval: split test . loss 9.898555e-02. error 3.29%. misses: 66
# 34
# eval: split train. loss 6.461775e-02. error 2.06%. misses: 149
# eval: split test . loss 7.923240e-02. error 2.49%. misses: 49
# 35
# eval: split train. loss 6.518593e-02. error 2.22%. misses: 161
# eval: split test . loss 7.341698e-02. error 2.14%. misses: 43
# 36
# eval: split train. loss 6.560259e-02. error 2.02%. misses: 146
# eval: split test . loss 7.728472e-02. error 2.24%. misses: 44
# 37
# eval: split train. loss 6.465713e-02. error 2.08%. misses: 152
# eval: split test . loss 7.754286e-02. error 2.49%. misses: 49
# 38
# eval: split train. loss 6.764556e-02. error 2.33%. misses: 169
# eval: split test . loss 7.916788e-02. error 2.74%. misses: 54
# 39
# eval: split train. loss 6.191163e-02. error 2.00%. misses: 145
# eval: split test . loss 7.680701e-02. error 2.34%. misses: 47
# 40
# eval: split train. loss 5.660351e-02. error 1.87%. misses: 135
# eval: split test . loss 7.464550e-02. error 2.69%. misses: 53
# 41
# eval: split train. loss 6.956656e-02. error 2.24%. misses: 162
# eval: split test . loss 8.881585e-02. error 3.29%. misses: 66
# 42
# eval: split train. loss 5.861463e-02. error 1.80%. misses: 130
# eval: split test . loss 7.103565e-02. error 2.54%. misses: 51
# 43
# eval: split train. loss 6.175054e-02. error 1.99%. misses: 145
# eval: split test . loss 7.730108e-02. error 2.29%. misses: 46
# 44
# eval: split train. loss 6.021497e-02. error 1.98%. misses: 143
# eval: split test . loss 7.768530e-02. error 2.29%. misses: 46
# 45
# eval: split train. loss 5.780318e-02. error 1.82%. misses: 133
# eval: split test . loss 7.734355e-02. error 2.34%. misses: 47
# 46
# eval: split train. loss 6.270958e-02. error 1.92%. misses: 139
# eval: split test . loss 8.063535e-02. error 2.84%. misses: 57
# 47
# eval: split train. loss 5.430164e-02. error 1.65%. misses: 119
# eval: split test . loss 7.453621e-02. error 2.44%. misses: 48
# 48
# eval: split train. loss 5.670655e-02. error 1.71%. misses: 125
# eval: split test . loss 8.066481e-02. error 2.74%. misses: 54
# 49
# eval: split train. loss 6.006388e-02. error 1.95%. misses: 142
# eval: split test . loss 8.068109e-02. error 2.74%. misses: 54
# 50
# eval: split train. loss 5.371173e-02. error 1.55%. misses: 113
# eval: split test . loss 8.431783e-02. error 2.69%. misses: 53
# 51
# eval: split train. loss 5.836643e-02. error 1.81%. misses: 131
# eval: split test . loss 8.814744e-02. error 2.94%. misses: 58
# 52
# eval: split train. loss 5.284856e-02. error 1.65%. misses: 119
# eval: split test . loss 7.456189e-02. error 2.29%. misses: 46
# 53
# eval: split train. loss 5.492195e-02. error 1.55%. misses: 113
# eval: split test . loss 7.251566e-02. error 2.39%. misses: 47
# 54
# eval: split train. loss 4.927309e-02. error 1.56%. misses: 114
# eval: split test . loss 6.782803e-02. error 2.19%. misses: 43
# 55
# eval: split train. loss 5.472878e-02. error 1.82%. misses: 133
# eval: split test . loss 7.636701e-02. error 2.44%. misses: 48
# 56
# eval: split train. loss 5.106088e-02. error 1.56%. misses: 114
# eval: split test . loss 7.587641e-02. error 2.74%. misses: 54
# 57
# eval: split train. loss 5.357588e-02. error 1.74%. misses: 126
# eval: split test . loss 7.444943e-02. error 2.49%. misses: 49
# 58
# eval: split train. loss 5.105072e-02. error 1.59%. misses: 115
# eval: split test . loss 6.981517e-02. error 1.89%. misses: 38
# 59
# eval: split train. loss 4.707626e-02. error 1.51%. misses: 109
# eval: split test . loss 7.113917e-02. error 2.24%. misses: 44
# 60
# eval: split train. loss 4.749453e-02. error 1.51%. misses: 109
# eval: split test . loss 6.519279e-02. error 1.84%. misses: 37
# 61
# eval: split train. loss 4.863371e-02. error 1.56%. misses: 114
# eval: split test . loss 6.735263e-02. error 2.04%. misses: 41
# 62
# eval: split train. loss 4.520619e-02. error 1.28%. misses: 92
# eval: split test . loss 6.786259e-02. error 1.84%. misses: 37
# 63
# eval: split train. loss 4.893922e-02. error 1.63%. misses: 118
# eval: split test . loss 7.432913e-02. error 2.19%. misses: 43
# 64
# eval: split train. loss 4.593049e-02. error 1.48%. misses: 108
# eval: split test . loss 7.338396e-02. error 2.29%. misses: 46
# 65
# eval: split train. loss 4.784581e-02. error 1.39%. misses: 100
# eval: split test . loss 7.090694e-02. error 1.99%. misses: 39
# 66
# eval: split train. loss 4.535353e-02. error 1.41%. misses: 102
# eval: split test . loss 7.269548e-02. error 2.39%. misses: 47
# 67
# eval: split train. loss 4.564472e-02. error 1.45%. misses: 106
# eval: split test . loss 6.969928e-02. error 2.24%. misses: 44
# 68
# eval: split train. loss 4.465084e-02. error 1.52%. misses: 111
# eval: split test . loss 6.938858e-02. error 2.39%. misses: 47
# 69
# eval: split train. loss 4.432216e-02. error 1.33%. misses: 96
# eval: split test . loss 6.695921e-02. error 2.24%. misses: 44
# 70
# eval: split train. loss 4.900645e-02. error 1.70%. misses: 123
# eval: split test . loss 7.316726e-02. error 2.44%. misses: 48
# 71
# eval: split train. loss 5.012999e-02. error 1.63%. misses: 118
# eval: split test . loss 7.211550e-02. error 2.24%. misses: 44
# 72
# eval: split train. loss 4.190568e-02. error 1.25%. misses: 90
# eval: split test . loss 6.363378e-02. error 2.24%. misses: 44
# 73
# eval: split train. loss 4.504418e-02. error 1.32%. misses: 96
# eval: split test . loss 7.157373e-02. error 2.19%. misses: 43
# 74
# eval: split train. loss 4.699726e-02. error 1.49%. misses: 109
# eval: split test . loss 6.800286e-02. error 2.09%. misses: 42
# 75
# eval: split train. loss 4.468146e-02. error 1.37%. misses: 100
# eval: split test . loss 6.937207e-02. error 2.24%. misses: 44
# 76
# eval: split train. loss 4.270818e-02. error 1.37%. misses: 100
# eval: split test . loss 7.132578e-02. error 2.14%. misses: 43
# 77
# eval: split train. loss 3.931551e-02. error 1.22%. misses: 88
# eval: split test . loss 6.670844e-02. error 2.44%. misses: 48
# 78
# eval: split train. loss 4.563647e-02. error 1.52%. misses: 111
# eval: split test . loss 7.015895e-02. error 2.29%. misses: 46
# 79
# eval: split train. loss 4.009823e-02. error 1.32%. misses: 96
# eval: split test . loss 6.705097e-02. error 2.24%. misses: 44
# 80
# eval: split train. loss 4.098034e-02. error 1.39%. misses: 100
# eval: split test . loss 6.641584e-02. error 1.84%. misses: 37

# %% [markdown]
# ### Original model with larger data set

# %% [markdown]
# We have used a series of modern "tricks" to improve the performance of the 1989 model, without changing its basic structure.
#
# But one of our best "tricks" for improving the performance of large neural networks is to increase the size and/or quality of the data on which the model is trained.
#
# It is interesting to see what performance we could have achieved in 1989 without any of those other "tricks" (some of which were not yet understood or widely used) - just using more data.

# %% [markdown]
# In the following cell, we preprocess the full MNIST dataset - 50,000 training samples and 10,000 test samples, rather than the 7291 and 2007 samples used in 1989 - to downsample them from 28x28 to 16x16.
#
# Then, we'll train that original 1989 model - *without* any of the changes we tried earlier - on this larger data set.

# %%
# The following code is adapted from "prepro.py" in the repository.

torch.manual_seed(1337)
np.random.seed(1337)

for split in {'train', 'test'}:

    data = datasets.MNIST('./data', train=split=='train', download=True)

    # Note: use full size data set
    n = 50000 if split == 'train' else 10000
    rp = np.random.permutation(len(data))[:n]

    X = torch.full((n, 1, 16, 16), 0.0, dtype=torch.float32)
    Y = torch.full((n, 10), -1.0, dtype=torch.float32)
    for i, ix in enumerate(rp):
        I, yint = data[int(ix)]
        # PIL image -> numpy -> torch tensor -> [-1, 1] fp32
        xi = torch.from_numpy(np.array(I, dtype=np.float32)) / 127.5 - 1.0
        # add a fake batch dimension and a channel dimension of 1 or F.interpolate won't be happy
        xi = xi[None, None, ...]
        # resize to (16, 16) images with bilinear interpolation
        xi = F.interpolate(xi, (16, 16), mode='bilinear')
        X[i] = xi[0] # store

        # set the correct class to have target of +1.0
        Y[i, yint] = 1.0

    torch.save((X, Y), split + 'full.pt')

# %%
learning_rate = 0.03

# init rng
torch.manual_seed(1337)
np.random.seed(1337)
torch.use_deterministic_algorithms(True)

# init a model
model = BaseNet()
print("model stats:")
print("# params:      ", sum(p.numel() for p in model.parameters())) # in paper total is 9,760
print("# MACs:        ", model.macs)
print("# activations: ", model.acts)

# init data
Xtr, Ytr = torch.load('trainfull.pt')
Xte, Yte = torch.load('testfull.pt')

# init optimizer
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

def eval_split(split):
    # eval the full train/test set, batched implementation for efficiency
    model.eval()
    X, Y = (Xtr, Ytr) if split == 'train' else (Xte, Yte)
    Yhat = model(X)
    loss = torch.mean((Y - Yhat)**2)
    err = torch.mean((Y.argmax(dim=1) != Yhat.argmax(dim=1)).float())
    print(f"eval: split {split:5s}. loss {loss.item():e}. error {err.item()*100:.2f}%. misses: {int(err.item()*Y.size(0))}")

# train
for pass_num in range(80):

    # perform one epoch of training
    model.train()
    for step_num in range(Xtr.size(0)):

        # fetch a single example into a batch of 1
        x, y = Xtr[[step_num]], Ytr[[step_num]]

        # forward the model and the loss
        yhat = model(x)
        loss = torch.mean((y - yhat)**2)

        # calculate the gradient and update the parameters
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # after epoch epoch evaluate the train and test error / metrics
    print(pass_num + 1)
    eval_split('train')
    eval_split('test')

# save final model to file
torch.save(model.state_dict(), 'base_model_data.pt')
# Out:
# model stats:
# # params:       9760
# # MACs:         63660
# # activations:  1000
# <ipython-input-18-49b6d7a7c3f8>:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr, Ytr = torch.load('trainfull.pt')
# <ipython-input-18-49b6d7a7c3f8>:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte, Yte = torch.load('testfull.pt')
# 1
# eval: split train. loss 3.373084e-02. error 5.10%. misses: 2551
# eval: split test . loss 3.295915e-02. error 5.06%. misses: 505
# 2
# eval: split train. loss 2.515974e-02. error 3.81%. misses: 1905
# eval: split test . loss 2.700199e-02. error 4.19%. misses: 419
# 3
# eval: split train. loss 2.133425e-02. error 3.21%. misses: 1603
# eval: split test . loss 2.360367e-02. error 3.73%. misses: 373
# 4
# eval: split train. loss 1.965277e-02. error 2.91%. misses: 1456
# eval: split test . loss 2.243822e-02. error 3.53%. misses: 353
# 5
# eval: split train. loss 1.900048e-02. error 2.79%. misses: 1393
# eval: split test . loss 2.182413e-02. error 3.40%. misses: 340
# 6
# eval: split train. loss 1.726790e-02. error 2.51%. misses: 1257
# eval: split test . loss 2.053956e-02. error 3.15%. misses: 315
# 7
# eval: split train. loss 1.789038e-02. error 2.68%. misses: 1341
# eval: split test . loss 2.123422e-02. error 3.21%. misses: 320
# 8
# eval: split train. loss 1.641336e-02. error 2.43%. misses: 1216
# eval: split test . loss 2.085022e-02. error 3.12%. misses: 311
# 9
# eval: split train. loss 1.805442e-02. error 2.70%. misses: 1348
# eval: split test . loss 2.263761e-02. error 3.42%. misses: 342
# 10
# eval: split train. loss 1.662692e-02. error 2.50%. misses: 1250
# eval: split test . loss 2.144318e-02. error 3.28%. misses: 328
# 11
# eval: split train. loss 1.568267e-02. error 2.31%. misses: 1154
# eval: split test . loss 2.143433e-02. error 3.17%. misses: 317
# 12
# eval: split train. loss 1.480088e-02. error 2.10%. misses: 1049
# eval: split test . loss 2.156767e-02. error 3.33%. misses: 333
# 13
# eval: split train. loss 1.391864e-02. error 2.01%. misses: 1006
# eval: split test . loss 1.965490e-02. error 2.93%. misses: 293
# 14
# eval: split train. loss 1.449702e-02. error 2.09%. misses: 1044
# eval: split test . loss 2.077802e-02. error 3.27%. misses: 326
# 15
# eval: split train. loss 1.509835e-02. error 2.19%. misses: 1092
# eval: split test . loss 2.083949e-02. error 3.25%. misses: 324
# 16
# eval: split train. loss 1.629462e-02. error 2.36%. misses: 1180
# eval: split test . loss 2.268893e-02. error 3.41%. misses: 340
# 17
# eval: split train. loss 1.555744e-02. error 2.28%. misses: 1138
# eval: split test . loss 2.117569e-02. error 3.38%. misses: 337
# 18
# eval: split train. loss 1.460409e-02. error 2.13%. misses: 1066
# eval: split test . loss 2.127772e-02. error 3.19%. misses: 318
# 19
# eval: split train. loss 1.306239e-02. error 1.87%. misses: 937
# eval: split test . loss 2.054957e-02. error 3.02%. misses: 302
# 20
# eval: split train. loss 1.481021e-02. error 2.14%. misses: 1071
# eval: split test . loss 2.227199e-02. error 3.25%. misses: 324
# 21
# eval: split train. loss 1.341412e-02. error 1.93%. misses: 965
# eval: split test . loss 2.105609e-02. error 3.30%. misses: 329
# 22
# eval: split train. loss 1.282640e-02. error 1.81%. misses: 906
# eval: split test . loss 2.066673e-02. error 3.14%. misses: 313
# 23
# eval: split train. loss 1.266621e-02. error 1.81%. misses: 906
# eval: split test . loss 2.060521e-02. error 3.13%. misses: 313
# 24
# eval: split train. loss 1.261194e-02. error 1.78%. misses: 889
# eval: split test . loss 2.105367e-02. error 3.20%. misses: 320
# 25
# eval: split train. loss 1.302214e-02. error 1.87%. misses: 937
# eval: split test . loss 2.043313e-02. error 3.10%. misses: 309
# 26
# eval: split train. loss 1.328394e-02. error 1.90%. misses: 949
# eval: split test . loss 2.074209e-02. error 3.09%. misses: 308
# 27
# eval: split train. loss 1.265952e-02. error 1.82%. misses: 910
# eval: split test . loss 2.006968e-02. error 3.05%. misses: 305
# 28
# eval: split train. loss 1.417392e-02. error 2.15%. misses: 1076
# eval: split test . loss 2.107293e-02. error 3.21%. misses: 320
# 29
# eval: split train. loss 1.368926e-02. error 1.97%. misses: 987
# eval: split test . loss 2.215772e-02. error 3.23%. misses: 322
# 30
# eval: split train. loss 1.229052e-02. error 1.80%. misses: 898
# eval: split test . loss 1.860259e-02. error 2.83%. misses: 283
# 31
# eval: split train. loss 1.280400e-02. error 1.80%. misses: 899
# eval: split test . loss 2.099834e-02. error 3.16%. misses: 315
# 32
# eval: split train. loss 1.255419e-02. error 1.83%. misses: 915
# eval: split test . loss 2.037076e-02. error 3.06%. misses: 306
# 33
# eval: split train. loss 1.286043e-02. error 1.83%. misses: 915
# eval: split test . loss 2.070985e-02. error 3.20%. misses: 320
# 34
# eval: split train. loss 1.510849e-02. error 2.17%. misses: 1087
# eval: split test . loss 2.236741e-02. error 3.28%. misses: 328
# 35
# eval: split train. loss 1.236302e-02. error 1.80%. misses: 901
# eval: split test . loss 1.982756e-02. error 3.02%. misses: 302
# 36
# eval: split train. loss 1.327857e-02. error 1.92%. misses: 961
# eval: split test . loss 2.027994e-02. error 3.06%. misses: 306
# 37
# eval: split train. loss 1.293292e-02. error 1.86%. misses: 932
# eval: split test . loss 2.135144e-02. error 3.16%. misses: 315
# 38
# eval: split train. loss 1.344448e-02. error 1.91%. misses: 953
# eval: split test . loss 2.012669e-02. error 3.13%. misses: 313
# 39
# eval: split train. loss 1.398501e-02. error 1.96%. misses: 982
# eval: split test . loss 2.176858e-02. error 3.24%. misses: 324
# 40
# eval: split train. loss 1.379181e-02. error 1.95%. misses: 973
# eval: split test . loss 2.196541e-02. error 3.26%. misses: 326
# 41
# eval: split train. loss 1.119858e-02. error 1.60%. misses: 798
# eval: split test . loss 1.995558e-02. error 2.95%. misses: 295
# 42
# eval: split train. loss 1.440404e-02. error 2.05%. misses: 1025
# eval: split test . loss 2.157133e-02. error 3.17%. misses: 317
# 43
# eval: split train. loss 1.490540e-02. error 2.18%. misses: 1090
# eval: split test . loss 2.159797e-02. error 3.20%. misses: 320
# 44
# eval: split train. loss 1.268291e-02. error 1.83%. misses: 917
# eval: split test . loss 2.182689e-02. error 3.24%. misses: 324
# 45
# eval: split train. loss 1.292448e-02. error 1.80%. misses: 901
# eval: split test . loss 2.182142e-02. error 3.18%. misses: 318
# 46
# eval: split train. loss 1.160810e-02. error 1.68%. misses: 839
# eval: split test . loss 2.059131e-02. error 3.14%. misses: 313
# 47
# eval: split train. loss 1.430020e-02. error 2.01%. misses: 1002
# eval: split test . loss 2.297175e-02. error 3.39%. misses: 339
# 48
# eval: split train. loss 1.640230e-02. error 2.35%. misses: 1173
# eval: split test . loss 2.308245e-02. error 3.28%. misses: 328
# 49
# eval: split train. loss 1.460108e-02. error 2.04%. misses: 1018
# eval: split test . loss 2.138782e-02. error 3.23%. misses: 322
# 50
# eval: split train. loss 1.254291e-02. error 1.83%. misses: 913
# eval: split test . loss 1.993715e-02. error 2.97%. misses: 296
# 51
# eval: split train. loss 1.513023e-02. error 2.11%. misses: 1056
# eval: split test . loss 2.205464e-02. error 3.21%. misses: 320
# 52
# eval: split train. loss 1.102228e-02. error 1.55%. misses: 775
# eval: split test . loss 2.071364e-02. error 3.07%. misses: 307
# 53
# eval: split train. loss 1.251326e-02. error 1.75%. misses: 872
# eval: split test . loss 2.153443e-02. error 3.32%. misses: 331
# 54
# eval: split train. loss 1.121137e-02. error 1.61%. misses: 807
# eval: split test . loss 2.017959e-02. error 2.96%. misses: 296
# 55
# eval: split train. loss 1.131638e-02. error 1.60%. misses: 801
# eval: split test . loss 2.036715e-02. error 3.10%. misses: 309
# 56
# eval: split train. loss 1.098159e-02. error 1.52%. misses: 757
# eval: split test . loss 1.991366e-02. error 3.03%. misses: 303
# 57
# eval: split train. loss 1.246955e-02. error 1.79%. misses: 892
# eval: split test . loss 2.174234e-02. error 3.20%. misses: 320
# 58
# eval: split train. loss 1.780087e-02. error 2.57%. misses: 1286
# eval: split test . loss 2.643219e-02. error 3.90%. misses: 390
# 59
# eval: split train. loss 1.368701e-02. error 1.96%. misses: 980
# eval: split test . loss 2.133834e-02. error 3.11%. misses: 310
# 60
# eval: split train. loss 1.368252e-02. error 1.94%. misses: 972
# eval: split test . loss 2.208231e-02. error 3.21%. misses: 320
# 61
# eval: split train. loss 1.481191e-02. error 2.11%. misses: 1054
# eval: split test . loss 2.245685e-02. error 3.35%. misses: 335
# 62
# eval: split train. loss 1.272017e-02. error 1.80%. misses: 899
# eval: split test . loss 2.226146e-02. error 3.35%. misses: 335
# 63
# eval: split train. loss 1.256377e-02. error 1.80%. misses: 898
# eval: split test . loss 2.211560e-02. error 3.35%. misses: 335
# 64
# eval: split train. loss 1.206912e-02. error 1.72%. misses: 860
# eval: split test . loss 2.184641e-02. error 3.28%. misses: 328
# 65
# eval: split train. loss 2.242273e-02. error 3.23%. misses: 1614
# eval: split test . loss 2.793877e-02. error 4.14%. misses: 414
# 66
# eval: split train. loss 1.383809e-02. error 1.96%. misses: 978
# eval: split test . loss 2.244823e-02. error 3.34%. misses: 333
# 67
# eval: split train. loss 1.331567e-02. error 1.87%. misses: 937
# eval: split test . loss 2.074960e-02. error 3.00%. misses: 299
# 68
# eval: split train. loss 1.130653e-02. error 1.59%. misses: 796
# eval: split test . loss 2.015514e-02. error 2.96%. misses: 296
# 69
# eval: split train. loss 9.882677e-03. error 1.37%. misses: 685
# eval: split test . loss 1.880090e-02. error 2.75%. misses: 274
# 70
# eval: split train. loss 1.248232e-02. error 1.73%. misses: 863
# eval: split test . loss 2.077247e-02. error 3.04%. misses: 304
# 71
# eval: split train. loss 1.287852e-02. error 1.80%. misses: 901
# eval: split test . loss 2.256232e-02. error 3.34%. misses: 333
# 72
# eval: split train. loss 1.420298e-02. error 2.05%. misses: 1027
# eval: split test . loss 2.326081e-02. error 3.32%. misses: 331
# 73
# eval: split train. loss 1.298090e-02. error 1.86%. misses: 930
# eval: split test . loss 2.199958e-02. error 3.31%. misses: 331
# 74
# eval: split train. loss 1.284672e-02. error 1.82%. misses: 908
# eval: split test . loss 2.107216e-02. error 3.07%. misses: 307
# 75
# eval: split train. loss 1.623009e-02. error 2.36%. misses: 1180
# eval: split test . loss 2.313163e-02. error 3.53%. misses: 353
# 76
# eval: split train. loss 1.274669e-02. error 1.83%. misses: 915
# eval: split test . loss 2.134717e-02. error 3.22%. misses: 322
# 77
# eval: split train. loss 1.988025e-02. error 2.90%. misses: 1449
# eval: split test . loss 2.626784e-02. error 3.87%. misses: 386
# 78
# eval: split train. loss 1.247091e-02. error 1.84%. misses: 918
# eval: split test . loss 1.945112e-02. error 2.92%. misses: 292
# 79
# eval: split train. loss 1.128560e-02. error 1.55%. misses: 775
# eval: split test . loss 2.117583e-02. error 3.14%. misses: 313
# 80
# eval: split train. loss 1.097814e-02. error 1.55%. misses: 774
# eval: split test . loss 1.991085e-02. error 3.08%. misses: 307

# %% [markdown]
# Using the original 1989 model,
#
# * with the "weird" MSE loss function,
# * tanh activation,
# * "plain" stochastic gradient descent with a fixed learning rate,
# * and no regularization,
#
# we still see a very respectable increase in performance just by training on more data (and since there is more data, adding more training passes.)

# %% [markdown]
# This would have substantially increased the training time in 1989 - the original model trained on 7291 training samples took 3 days to train, and this training set is about 7x that size - but the inference time would not have been affected.

# %% [markdown]
# ### Modern model with larger data set

# %% [markdown]
# Finally, let's see how our "modern" updated neural network does when trained on the larger dataset - 50,000 training samples.

# %%
class ModernNet(nn.Module):

    def __init__(self):
        super().__init__()

        # initialization as described in the paper to my best ability, but it doesn't look right...
        winit = lambda fan_in, *shape: (torch.rand(*shape) - 0.5) * 2 * 2.4 / fan_in**0.5
        macs = 0 # keep track of MACs (multiply accumulates)
        acts = 0 # keep track of number of activations

        # H1 layer parameters and their initialization
        self.H1w = nn.Parameter(winit(5*5*1, 12, 1, 5, 5))
        self.H1b = nn.Parameter(torch.zeros(12, 8, 8)) # presumably init to zero for biases
        macs += (5*5*1) * (8*8) * 12
        acts += (8*8) * 12

        # H2 layer parameters and their initialization
        """
        H2 neurons all connect to only 8 of the 12 input planes, with an unspecified pattern
        I am going to assume the most sensible block pattern where 4 planes at a time connect
        to differently overlapping groups of 8/12 input planes. We will implement this with 3
        separate convolutions that we concatenate the results of.
        """
        self.H2w = nn.Parameter(winit(5*5*8, 12, 8, 5, 5))
        self.H2b = nn.Parameter(torch.zeros(12, 4, 4)) # presumably init to zero for biases
        macs += (5*5*8) * (4*4) * 12
        acts += (4*4) * 12

        # H3 is a fully connected layer
        self.H3w = nn.Parameter(winit(4*4*12, 4*4*12, 30))
        self.H3b = nn.Parameter(torch.zeros(30))
        macs += (4*4*12) * 30
        acts += 30

        # output layer is also fully connected layer
        self.outw = nn.Parameter(winit(30, 30, 10))
        self.outb = nn.Parameter(torch.zeros(10))
        macs += 30 * 10
        acts += 10

        self.macs = macs
        self.acts = acts

    def forward(self, x):

        # poor man's data augmentation by 1 pixel along x/y directions
        if self.training:
            shift_x, shift_y = np.random.randint(-1, 2, size=2)
            x = torch.roll(x, (shift_x, shift_y), (2, 3))

        # x has shape (1, 1, 16, 16)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        x = F.conv2d(x, self.H1w, stride=2) + self.H1b
        x = torch.relu(x) # Note: ReLU activation!

        # x is now shape (1, 12, 8, 8)
        x = F.pad(x, (2, 2, 2, 2), 'constant', -1.0) # pad by two using constant -1 for background
        slice1 = F.conv2d(x[:, 0:8], self.H2w[0:4], stride=2) # first 4 planes look at first 8 input planes
        slice2 = F.conv2d(x[:, 4:12], self.H2w[4:8], stride=2) # next 4 planes look at last 8 input planes
        slice3 = F.conv2d(torch.cat((x[:, 0:4], x[:, 8:12]), dim=1), self.H2w[8:12], stride=2) # last 4 planes are cross
        x = torch.cat((slice1, slice2, slice3), dim=1) + self.H2b
        x = torch.relu(x) # Note: ReLU activation!

        # x is now shape (1, 12, 4, 4)
        x = x.flatten(start_dim=1) # (1, 12*4*4)
        x = x @ self.H3w + self.H3b
        x = torch.relu(x) # Note: ReLU activation!
        x = F.dropout(x, p=0.25, training=self.training) # Note: dropout layer!


        # x is now shape (1, 30)
        x = x @ self.outw + self.outb

         # x is finally shape (1, 10)
        return x

# %%
# The following code is adapted from "modern.py" in the repository.

learning_rate = 3e-4

# init rng
torch.manual_seed(1337)
np.random.seed(1337)
torch.use_deterministic_algorithms(True)

# init a model
model = ModernNet()
print("model stats:")
print("# params:      ", sum(p.numel() for p in model.parameters())) # in paper total is 9,760
print("# MACs:        ", model.macs)
print("# activations: ", model.acts)

# init data
Xtr, Ytr = torch.load('trainfull.pt')
Xte, Yte = torch.load('testfull.pt')

# init optimizer
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

def eval_split(split):
    # eval the full train/test set, batched implementation for efficiency
    model.eval()
    X, Y = (Xtr, Ytr) if split == 'train' else (Xte, Yte)
    Yhat = model(X)
    loss = F.cross_entropy(Yhat, Y.argmax(dim=1))
    err = torch.mean((Y.argmax(dim=1) != Yhat.argmax(dim=1)).float())
    print(f"eval: split {split:5s}. loss {loss.item():e}. error {err.item()*100:.2f}%. misses: {int(err.item()*Y.size(0))}")

# train
for pass_num in range(80):

    # learning rate decay
    alpha = pass_num / 79
    for g in optimizer.param_groups:
        g['lr'] = (1 - alpha) * learning_rate + alpha * (learning_rate / 3)

    # perform one epoch of training
    model.train()
    for step_num in range(Xtr.size(0)):

        # fetch a single example into a batch of 1
        x, y = Xtr[[step_num]], Ytr[[step_num]]

        # forward the model and the loss
        yhat = model(x)
        loss = F.cross_entropy(yhat, y.argmax(dim=1))

        # calculate the gradient and update the parameters
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # after epoch epoch evaluate the train and test error / metrics
    print(pass_num + 1)
    eval_split('train')
    eval_split('test')

# save final model to file
torch.save(model.state_dict(), 'modern_model_data.pt')
# Out:
# model stats:
# # params:       9760
# # MACs:         63660
# # activations:  1000
# <ipython-input-20-a790e6c022df>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xtr, Ytr = torch.load('trainfull.pt')
# <ipython-input-20-a790e6c022df>:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Xte, Yte = torch.load('testfull.pt')
# 1
# eval: split train. loss 1.828735e-01. error 5.38%. misses: 2687
# eval: split test . loss 1.699664e-01. error 4.84%. misses: 483
# 2
# eval: split train. loss 1.426048e-01. error 4.35%. misses: 2175
# eval: split test . loss 1.249981e-01. error 3.86%. misses: 386
# 3
# eval: split train. loss 1.095773e-01. error 3.44%. misses: 1719
# eval: split test . loss 9.419119e-02. error 3.06%. misses: 306
# 4
# eval: split train. loss 9.529873e-02. error 2.91%. misses: 1455
# eval: split test . loss 8.429552e-02. error 2.61%. misses: 261
# 5
# eval: split train. loss 1.065783e-01. error 3.24%. misses: 1620
# eval: split test . loss 9.103058e-02. error 2.74%. misses: 274
# 6
# eval: split train. loss 1.046516e-01. error 3.10%. misses: 1549
# eval: split test . loss 9.008165e-02. error 2.78%. misses: 277
# 7
# eval: split train. loss 8.647890e-02. error 2.64%. misses: 1320
# eval: split test . loss 7.815118e-02. error 2.43%. misses: 242
# 8
# eval: split train. loss 7.868447e-02. error 2.29%. misses: 1143
# eval: split test . loss 6.709084e-02. error 1.99%. misses: 198
# 9
# eval: split train. loss 7.584153e-02. error 2.34%. misses: 1169
# eval: split test . loss 6.475678e-02. error 2.08%. misses: 208
# 10
# eval: split train. loss 8.234077e-02. error 2.51%. misses: 1255
# eval: split test . loss 7.210888e-02. error 2.43%. misses: 242
# 11
# eval: split train. loss 9.137657e-02. error 2.83%. misses: 1415
# eval: split test . loss 8.028938e-02. error 2.58%. misses: 258
# 12
# eval: split train. loss 7.723510e-02. error 2.29%. misses: 1145
# eval: split test . loss 6.666691e-02. error 2.14%. misses: 214
# 13
# eval: split train. loss 7.735533e-02. error 2.41%. misses: 1202
# eval: split test . loss 6.585585e-02. error 2.19%. misses: 219
# 14
# eval: split train. loss 6.995634e-02. error 2.18%. misses: 1087
# eval: split test . loss 6.209213e-02. error 2.06%. misses: 206
# 15
# eval: split train. loss 7.479383e-02. error 2.27%. misses: 1133
# eval: split test . loss 6.943733e-02. error 2.18%. misses: 218
# 16
# eval: split train. loss 7.176290e-02. error 2.24%. misses: 1121
# eval: split test . loss 5.862548e-02. error 1.88%. misses: 187
# 17
# eval: split train. loss 8.080773e-02. error 2.42%. misses: 1209
# eval: split test . loss 6.696292e-02. error 2.13%. misses: 212
# 18
# eval: split train. loss 7.079867e-02. error 2.07%. misses: 1037
# eval: split test . loss 6.069728e-02. error 1.79%. misses: 178
# 19
# eval: split train. loss 6.889509e-02. error 2.08%. misses: 1037
# eval: split test . loss 5.871560e-02. error 1.87%. misses: 186
# 20
# eval: split train. loss 7.717240e-02. error 2.31%. misses: 1152
# eval: split test . loss 6.380410e-02. error 1.92%. misses: 192
# 21
# eval: split train. loss 6.583146e-02. error 2.04%. misses: 1020
# eval: split test . loss 5.897053e-02. error 1.86%. misses: 186
# 22
# eval: split train. loss 6.465035e-02. error 2.05%. misses: 1027
# eval: split test . loss 5.571495e-02. error 1.84%. misses: 184
# 23
# eval: split train. loss 6.901069e-02. error 2.09%. misses: 1047
# eval: split test . loss 5.962103e-02. error 1.91%. misses: 190
# 24
# eval: split train. loss 6.428115e-02. error 1.89%. misses: 946
# eval: split test . loss 5.611250e-02. error 1.68%. misses: 167
# 25
# eval: split train. loss 6.962250e-02. error 2.17%. misses: 1083
# eval: split test . loss 6.106241e-02. error 1.98%. misses: 197
# 26
# eval: split train. loss 6.371494e-02. error 2.00%. misses: 999
# eval: split test . loss 5.751491e-02. error 1.88%. misses: 187
# 27
# eval: split train. loss 6.433979e-02. error 1.97%. misses: 982
# eval: split test . loss 5.303263e-02. error 1.73%. misses: 173
# 28
# eval: split train. loss 6.940416e-02. error 2.11%. misses: 1056
# eval: split test . loss 6.356432e-02. error 2.01%. misses: 200
# 29
# eval: split train. loss 6.552669e-02. error 2.02%. misses: 1009
# eval: split test . loss 5.418845e-02. error 1.77%. misses: 176
# 30
# eval: split train. loss 7.110635e-02. error 2.14%. misses: 1070
# eval: split test . loss 6.080040e-02. error 1.92%. misses: 192
# 31
# eval: split train. loss 6.621417e-02. error 2.04%. misses: 1020
# eval: split test . loss 5.665530e-02. error 1.77%. misses: 176
# 32
# eval: split train. loss 6.450122e-02. error 2.01%. misses: 1006
# eval: split test . loss 5.616797e-02. error 1.75%. misses: 175
# 33
# eval: split train. loss 6.528495e-02. error 2.05%. misses: 1025
# eval: split test . loss 5.858025e-02. error 1.92%. misses: 192
# 34
# eval: split train. loss 7.132266e-02. error 2.16%. misses: 1082
# eval: split test . loss 5.859509e-02. error 1.82%. misses: 182
# 35
# eval: split train. loss 6.048287e-02. error 1.82%. misses: 910
# eval: split test . loss 5.479584e-02. error 1.80%. misses: 179
# 36
# eval: split train. loss 7.947338e-02. error 2.41%. misses: 1207
# eval: split test . loss 6.778555e-02. error 2.01%. misses: 200
# 37
# eval: split train. loss 6.066554e-02. error 1.90%. misses: 949
# eval: split test . loss 5.126215e-02. error 1.63%. misses: 163
# 38
# eval: split train. loss 7.205281e-02. error 2.15%. misses: 1075
# eval: split test . loss 6.171887e-02. error 1.89%. misses: 188
# 39
# eval: split train. loss 6.078120e-02. error 1.82%. misses: 910
# eval: split test . loss 5.703661e-02. error 1.81%. misses: 181
# 40
# eval: split train. loss 6.215044e-02. error 1.89%. misses: 942
# eval: split test . loss 5.678688e-02. error 1.74%. misses: 174
# 41
# eval: split train. loss 5.602748e-02. error 1.71%. misses: 853
# eval: split test . loss 4.969541e-02. error 1.61%. misses: 161
# 42
# eval: split train. loss 6.653250e-02. error 2.01%. misses: 1004
# eval: split test . loss 6.278646e-02. error 1.85%. misses: 185
# 43
# eval: split train. loss 6.008426e-02. error 1.85%. misses: 927
# eval: split test . loss 5.527921e-02. error 1.75%. misses: 175
# 44
# eval: split train. loss 6.206508e-02. error 1.89%. misses: 946
# eval: split test . loss 5.781152e-02. error 1.87%. misses: 186
# 45
# eval: split train. loss 5.431242e-02. error 1.64%. misses: 822
# eval: split test . loss 4.676562e-02. error 1.50%. misses: 149
# 46
# eval: split train. loss 5.724601e-02. error 1.87%. misses: 932
# eval: split test . loss 5.348635e-02. error 1.75%. misses: 175
# 47
# eval: split train. loss 5.668841e-02. error 1.75%. misses: 874
# eval: split test . loss 4.998032e-02. error 1.44%. misses: 143
# 48
# eval: split train. loss 6.113131e-02. error 1.88%. misses: 939
# eval: split test . loss 5.504033e-02. error 1.69%. misses: 168
# 49
# eval: split train. loss 5.441854e-02. error 1.70%. misses: 848
# eval: split test . loss 4.800943e-02. error 1.50%. misses: 149
# 50
# eval: split train. loss 6.104916e-02. error 1.86%. misses: 930
# eval: split test . loss 5.444012e-02. error 1.67%. misses: 166
# 51
# eval: split train. loss 6.008510e-02. error 1.81%. misses: 903
# eval: split test . loss 5.488982e-02. error 1.75%. misses: 175
# 52
# eval: split train. loss 5.588210e-02. error 1.73%. misses: 863
# eval: split test . loss 4.949044e-02. error 1.51%. misses: 151
# 53
# eval: split train. loss 6.216387e-02. error 1.97%. misses: 984
# eval: split test . loss 5.565095e-02. error 1.74%. misses: 174
# 54
# eval: split train. loss 6.126429e-02. error 1.89%. misses: 946
# eval: split test . loss 5.573785e-02. error 1.72%. misses: 172
# 55
# eval: split train. loss 6.282264e-02. error 1.92%. misses: 958
# eval: split test . loss 5.774290e-02. error 1.82%. misses: 182
# 56
# eval: split train. loss 5.335981e-02. error 1.66%. misses: 827
# eval: split test . loss 4.922632e-02. error 1.60%. misses: 160
# 57
# eval: split train. loss 5.252047e-02. error 1.58%. misses: 788
# eval: split test . loss 4.847418e-02. error 1.48%. misses: 148
# 58
# eval: split train. loss 5.662934e-02. error 1.77%. misses: 884
# eval: split test . loss 5.254818e-02. error 1.66%. misses: 165
# 59
# eval: split train. loss 5.406445e-02. error 1.63%. misses: 815
# eval: split test . loss 5.076608e-02. error 1.54%. misses: 153
# 60
# eval: split train. loss 6.368358e-02. error 1.99%. misses: 994
# eval: split test . loss 5.510111e-02. error 1.76%. misses: 175
# 61
# eval: split train. loss 5.785965e-02. error 1.74%. misses: 870
# eval: split test . loss 5.351149e-02. error 1.73%. misses: 173
# 62
# eval: split train. loss 5.349755e-02. error 1.65%. misses: 824
# eval: split test . loss 4.888071e-02. error 1.49%. misses: 148
# 63
# eval: split train. loss 5.664927e-02. error 1.71%. misses: 856
# eval: split test . loss 4.959281e-02. error 1.51%. misses: 151
# 64
# eval: split train. loss 5.987836e-02. error 1.80%. misses: 899
# eval: split test . loss 5.413450e-02. error 1.68%. misses: 167
# 65
# eval: split train. loss 5.571306e-02. error 1.74%. misses: 868
# eval: split test . loss 5.012967e-02. error 1.56%. misses: 155
# 66
# eval: split train. loss 5.415460e-02. error 1.72%. misses: 862
# eval: split test . loss 4.868736e-02. error 1.54%. misses: 153
# 67
# eval: split train. loss 6.191102e-02. error 1.84%. misses: 918
# eval: split test . loss 5.845397e-02. error 1.86%. misses: 186
# 68
# eval: split train. loss 5.467705e-02. error 1.68%. misses: 839
# eval: split test . loss 4.907722e-02. error 1.45%. misses: 144
# 69
# eval: split train. loss 5.421477e-02. error 1.68%. misses: 837
# eval: split test . loss 4.849193e-02. error 1.61%. misses: 161
# 70
# eval: split train. loss 4.813532e-02. error 1.54%. misses: 771
# eval: split test . loss 4.296386e-02. error 1.48%. misses: 148
# 71
# eval: split train. loss 5.010903e-02. error 1.56%. misses: 779
# eval: split test . loss 4.510155e-02. error 1.42%. misses: 142
# 72
# eval: split train. loss 5.208831e-02. error 1.64%. misses: 820
# eval: split test . loss 4.591072e-02. error 1.50%. misses: 149
# 73
# eval: split train. loss 5.508640e-02. error 1.73%. misses: 867
# eval: split test . loss 4.701288e-02. error 1.46%. misses: 146
# 74
# eval: split train. loss 5.070626e-02. error 1.48%. misses: 740
# eval: split test . loss 4.593458e-02. error 1.50%. misses: 149
# 75
# eval: split train. loss 5.239534e-02. error 1.54%. misses: 772
# eval: split test . loss 4.764478e-02. error 1.54%. misses: 153
# 76
# eval: split train. loss 5.177980e-02. error 1.55%. misses: 777
# eval: split test . loss 5.047558e-02. error 1.60%. misses: 160
# 77
# eval: split train. loss 5.538420e-02. error 1.56%. misses: 780
# eval: split test . loss 4.921980e-02. error 1.38%. misses: 137
# 78
# eval: split train. loss 4.815406e-02. error 1.44%. misses: 718
# eval: split test . loss 4.321169e-02. error 1.41%. misses: 141
# 79
# eval: split train. loss 5.066914e-02. error 1.54%. misses: 768
# eval: split test . loss 4.466170e-02. error 1.41%. misses: 141
# 80
# eval: split train. loss 5.589447e-02. error 1.68%. misses: 839
# eval: split test . loss 5.006086e-02. error 1.61%. misses: 161

# %% [markdown]
# With the extra data, our "updated" version of the 1989 model, with
#
# * MSE loss changed to cross entropy loss
# * tanh activation changed to ReLU
# * SGD with constant learning rate changed to Adam with learning rate decay
# * added dropout layer for regularization
# * basic data augmentation (shift up to 1 pixel in each direction)
#
# but the same basic structure, easily achieves less than 2% error.

# %% [markdown]
# ## Summary of results
#
# To summarize, the test error rate of each model was:
#
# * Original 1989 paper: **5.0%**
# * Pytorch model based on original: **4.14%**
# * ... + cross entropy loss: **4.58%**
# * ... + Adam optimizer: **3.64%**
# * ... + data augmentation: **2.29%**
# * ... + dropout + ReLU activations: **2.09%**
# * ... + more training data: **1.31%**
#
# and,
#
# * Pytorch model based on 1989 original + more training data: about **3.05%**
