# %% [markdown]
# # Demo: Neural network for classification
#
# ------------------------------------------------------------------------
#
# *Fraida Fund*

# %% [markdown]
# *<small>Attribution: Some parts of this notebook are written by Sundeep Rangan, from his [IntroML GitHub repo](https://github.com/sdrangan/introml/).</small>*

# %% [markdown]
# We previously considered a general approach to learning a non-linear function of the input data: we can supply a non-linear data representation, by applying a non-linear transformation to the input data, or specifying a non-linear kernel. Then, the machine learning model learns from the transformed data.
#
# The power of neural networks is their ability to *learn* a “transformation”, rather than having to specify it ourselves! In this demo, we will see how.

# %% [markdown]
# ## Draw a classification problem

# %% [markdown]
# In the following cell, draw on the canvas to fill in the region of the feature space that should be part of the positive class.

# %%
#@title ### Colab drawing magic
# colab drawing magic via
# https://gist.github.com/korakot/8409b3feec20f159d8a50b0a811d3bca
from IPython.display import HTML, Image
from google.colab.output import eval_js
from base64 import b64decode

canvas_html = """
<canvas width=%d height=%d style='border:1px solid #000000;'></canvas>
<button>Finish</button>
<script>
var canvas = document.querySelector('canvas')
var ctx = canvas.getContext('2d')
ctx.lineWidth = %d
var button = document.querySelector('button')
var mouse = {x: 0, y: 0}

canvas.addEventListener('mousemove', function(e) {
  mouse.x = e.pageX - this.offsetLeft
  mouse.y = e.pageY - this.offsetTop
})
canvas.onmousedown = ()=>{
  ctx.beginPath()
  ctx.moveTo(mouse.x, mouse.y)
  canvas.addEventListener('mousemove', onPaint)
}
canvas.onmouseup = ()=>{
  canvas.removeEventListener('mousemove', onPaint)
}
var onPaint = ()=>{
  ctx.lineTo(mouse.x, mouse.y)
  ctx.stroke()
}

var data = new Promise(resolve=>{
  button.onclick = ()=>{
    resolve(canvas.toDataURL('image/png'))
  }
})
</script>
"""

def draw(filename='drawing.png', w=256, h=256, line_width=10):
  display(HTML(canvas_html % (w, h, line_width)))
  data = eval_js("data")
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)

# %%
draw()

# %%
from PIL import Image
import numpy as np
im = Image.open("drawing.png")
np_im = np.array(im)
print(np_im.shape)
# Out:
# (256, 256, 4)

# %%
np_im_bw = np_im[:,:,3]

# %%
import matplotlib.pyplot as plt

plt.imshow(np_im_bw, cmap='binary');
plt.xlim(0,255);
plt.ylim(255,0);
plt.xlabel('x1');
plt.ylabel('x2');

# %% [markdown]
# ## Get training, validation, and test data

# %%
n_train = 5000
n_val   = 1000
n_test  = 10000

X_train = np.column_stack((np.random.randint(0, np_im_bw.shape[0], size=n_train), np.random.randint(0, np_im_bw.shape[1], size=n_train)))
y_train = np.rot90(np_im_bw, k=3)[X_train[:,0], X_train[:,1]]

X_train = X_train/255.0
y_train = y_train/255.0


X_val = np.column_stack((np.random.randint(0, np_im_bw.shape[0], size=n_val), np.random.randint(0, np_im_bw.shape[1], size=n_val)))
y_val = np.rot90(np_im_bw, k=3)[X_val[:,0], X_val[:,1]]

X_val = X_val/255.0
y_val = y_val/255.0


X_test = np.column_stack((np.random.randint(0, np_im_bw.shape[0], size=n_test), np.random.randint(0, np_im_bw.shape[1], size=n_test)))
y_test = np.rot90(np_im_bw, k=3)[X_test[:,0], X_test[:,1]]

X_test = X_test/255.0
y_test = y_test/255.0

# %%
# %pip install seaborn
import seaborn as sns

plt.scatter(x=X_train[:,0], y=X_train[:,1], c=y_train, cmap='binary', edgecolors= "gray")
plt.xlabel("x1");
plt.ylabel("x2");
plt.title("Training data");
# Out:
# Requirement already satisfied: seaborn in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\cj\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Import Tensorflow + Keras

# %% [markdown]
# For this demo, we will use Tensorflow with Keras to train and configure a neural network.
#
# Tensorflow is a powerful and widely-used platform for deep learning. However, Tensorflow is relatively low level and may be somewhat difficult to use as a starting point. We will use the `keras` package which acts as a high-level wrapper on top of tensorflow that allows you to quickly build and fit models.
#
# (A very popular alternative to Tensorflow for working with neural networks is PyTorch - you can read more about PyTorch [here](https://pytorch.org/).)

# %% [markdown]
# First we import Tensorflow.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# (There are two major versions of Tensorflow. Code that was written for TF1 often will not run with TF2. The current version is TF2.)

# %% [markdown]
# ## Create the neural network

# %% [markdown]
# We will see if we can build a simple neural network classifier to learn the decision region that we drew above.

# %% [markdown]
# We first import some key sub-packages from `keras`.

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Activation, Input

# %% [markdown]
# Keras keeps track of computational graphs behind the scenes, and sometimes (e.g. you run this notebook several times) it may be holding on to computational graphs for models that are no longer in scope (e.g. you no longer have a variable pointing to that model). The following command frees up memory for those models, just in case.

# %%
import tensorflow.keras.backend as K
K.clear_session()

# %% [markdown]
# Now we create a very simple network.
#
# The neural network has `nin=2` input units, corresponding to the two features.
#
# It has one hidden layer with `nh=4` hidden units. Each hidden unit will use a sigmoid activation function.
#
# There is `nout=1` output unit corresponding to the estimated class label. This unit will also have a sigmoid activation function.
#
# <small>Reference: [TF+keras activations](https://www.tensorflow.org/api_docs/python/tf/keras/activations).</small>

# %% [markdown]
# All of the layers are *dense* or *fully connected* layers, meaning that each node has a link to every node in the adjacent layers.
#
# <small>Reference: [Keras layers](https://keras.io/api/layers/)</small>

# %%
nin = 2  # dimension of input data
nh = 10  # number of hidden units
nout = 1  # number of outputs = 1 since this is binary
model = Sequential()
model.add(Input(shape=(nin,)))
model.add(Dense(units=nh, activation='sigmoid', name='hidden'))
model.add(Dense(units=nout, activation='sigmoid', name='output'))

# %% [markdown]
# (Note: a previous version of this notebook specified the input shape in the first hidden layer, instead of having a separate `Input`, but this practice is no longer recommended.)

# %% [markdown]
# In our visualization of the network architechture, we will also add a *bias node* at each layer. This simplifies the computation of weights by adding an extra input whose value is always 1. The bias term then comes from the weight applied to that input.

# %%
#@title Visualize the network architecture
# %pip install networkx matplotlib
import networkx as nx
inputLayerSize  = nin
outputLayerSize = nout
hiddenLayerSize = nh


nodePos = {}
G=nx.Graph()
graphHeight = max(inputLayerSize, outputLayerSize, hiddenLayerSize)

# create nodes and note their positions
for n in range(inputLayerSize):
  nodePos['x'+str(n+1)]=(1, n)
  G.add_node('x'+str(n+1))
for n in range(outputLayerSize):
  nodePos['o'+str(n+1)]=(5, n)
  G.add_node('o'+str(n+1))
for n in range(hiddenLayerSize):
  nodePos['h'+str(n+1)]=(3, n)
  G.add_node('h'+str(n+1))

# add edges
for n in range(hiddenLayerSize):
  for m in range(inputLayerSize):
    G.add_edge('x' + str(m+1), 'h' + str(n+1))
  for m in range(outputLayerSize):
    G.add_edge('h' + str(n+1), 'o' + str(m+1))

# add bias nodes

nodePos['xb']=(1, inputLayerSize)
G.add_node('xb')
for n in range(hiddenLayerSize):
  G.add_edge('xb', 'h' + str(n+1))

nodePos['hb']=(3, hiddenLayerSize)
G.add_node('hb')
for n in range(outputLayerSize):
  G.add_edge('hb', 'o' + str(n+1))

nx.draw_networkx(G, pos=nodePos,
              node_size=1000, node_color='pink')
plt.axis('off');
plt.margins(0.2, 0.2);
# Out:
# Requirement already satisfied: networkx in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.4.2)
# Requirement already satisfied: matplotlib in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\cj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\cj\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# Each node in the neural network applies its activation function to the weighted sum of its inputs, then passes that as output to the nodes in the next layer.
#
# The neural network needs to learn a weight for each link in the image above (including the weights for the bias nodes).

# %% [markdown]
# Keras has a nice command for summarizing the network architecture:

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden (Dense)                  │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Next, we have to select an optimizer and a loss function.
#
# Since this is a binary classification problem, we select the `binary_crossentropy` loss.
#
# We will also choose an optimizer (Adam) and a learning rate of `learning_rate=0.01`.
#
# We also set the `metrics` that we wish to track during the optimization. In this case, we select `accuracy` on the training set.
#
# Finally, before training, we must `compile` the model.
#
# <small>Reference: [TF+keras loss functions](https://www.tensorflow.org/api_docs/python/tf/keras/losses), [Keras optimizers](https://keras.io/api/optimizers/)</small>

# %%
from tensorflow.keras import optimizers

opt = optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Train the neural network

# %% [markdown]
# Keras provides a simple method `fit` to run the optimization. You simply specify the number of epochs and the batch size.
#
# We will also pass it some `validation_data` - it will also compute the loss and accuracy on the validation data at each epoch.
#
# (During one epoch, we run as many iterations of mini-batch stochastic gradient descent as it takes to sample all the training data, without replacement.)

# %%
hist = model.fit(X_train, y_train, epochs=100, batch_size=1, validation_data=(X_val,y_val))
# Out:
# Epoch 1/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.8391 - loss: 0.4507 - val_accuracy: 0.8440 - val_loss: 0.4390
# Epoch 2/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.8367 - loss: 0.4370 - val_accuracy: 0.8440 - val_loss: 0.3906
# Epoch 3/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.8382 - loss: 0.3808 - val_accuracy: 0.8440 - val_loss: 0.2998
# Epoch 4/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.8661 - loss: 0.2755 - val_accuracy: 0.9170 - val_loss: 0.2163
# Epoch 5/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9107 - loss: 0.2126 - val_accuracy: 0.9300 - val_loss: 0.1837
# Epoch 6/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9222 - loss: 0.1932 - val_accuracy: 0.9430 - val_loss: 0.1712
# Epoch 7/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9190 - loss: 0.1844 - val_accuracy: 0.8690 - val_loss: 0.2532
# Epoch 8/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9370 - loss: 0.1641 - val_accuracy: 0.9280 - val_loss: 0.1533
# Epoch 9/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9374 - loss: 0.1518 - val_accuracy: 0.9410 - val_loss: 0.1388
# Epoch 10/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9350 - loss: 0.1514 - val_accuracy: 0.9330 - val_loss: 0.1741
# Epoch 11/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9399 - loss: 0.1449 - val_accuracy: 0.9470 - val_loss: 0.1286
# Epoch 12/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9428 - loss: 0.1377 - val_accuracy: 0.9420 - val_loss: 0.1415
# Epoch 13/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9411 - loss: 0.1397 - val_accuracy: 0.9580 - val_loss: 0.1257
# Epoch 14/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.9447 - loss: 0.1331 - val_accuracy: 0.9550 - val_loss: 0.1226
# Epoch 15/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9433 - loss: 0.1294 - val_accuracy: 0.9480 - val_loss: 0.1175
# Epoch 16/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9494 - loss: 0.1238 - val_accuracy: 0.9450 - val_loss: 0.1175
# Epoch 17/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9474 - loss: 0.1271 - val_accuracy: 0.9250 - val_loss: 0.1629
# Epoch 18/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9396 - loss: 0.1352 - val_accuracy: 0.9550 - val_loss: 0.1185
# Epoch 19/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9523 - loss: 0.1228 - val_accuracy: 0.9280 - val_loss: 0.1587
# Epoch 20/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9444 - loss: 0.1326 - val_accuracy: 0.9380 - val_loss: 0.1307
# Epoch 21/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9524 - loss: 0.1173 - val_accuracy: 0.9550 - val_loss: 0.1161
# Epoch 22/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9450 - loss: 0.1209 - val_accuracy: 0.9380 - val_loss: 0.1425
# Epoch 23/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9458 - loss: 0.1237 - val_accuracy: 0.9500 - val_loss: 0.1173
# Epoch 24/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9454 - loss: 0.1192 - val_accuracy: 0.9440 - val_loss: 0.1135
# Epoch 25/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9527 - loss: 0.1117 - val_accuracy: 0.9620 - val_loss: 0.0991
# Epoch 26/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9558 - loss: 0.1149 - val_accuracy: 0.9650 - val_loss: 0.0967
# Epoch 27/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9532 - loss: 0.1081 - val_accuracy: 0.9540 - val_loss: 0.0984
# Epoch 28/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9559 - loss: 0.1025 - val_accuracy: 0.9380 - val_loss: 0.1192
# Epoch 29/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9513 - loss: 0.1031 - val_accuracy: 0.9690 - val_loss: 0.0869
# Epoch 30/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9586 - loss: 0.0995 - val_accuracy: 0.9460 - val_loss: 0.1045
# Epoch 31/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9584 - loss: 0.1002 - val_accuracy: 0.9670 - val_loss: 0.0848
# Epoch 32/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9522 - loss: 0.1058 - val_accuracy: 0.9670 - val_loss: 0.0843
# Epoch 33/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9606 - loss: 0.0954 - val_accuracy: 0.9530 - val_loss: 0.1012
# Epoch 34/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9602 - loss: 0.0887 - val_accuracy: 0.9580 - val_loss: 0.0929
# Epoch 35/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9615 - loss: 0.0955 - val_accuracy: 0.9690 - val_loss: 0.0831
# Epoch 36/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9533 - loss: 0.0998 - val_accuracy: 0.9690 - val_loss: 0.0776
# Epoch 37/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9662 - loss: 0.0836 - val_accuracy: 0.9590 - val_loss: 0.0880
# Epoch 38/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - accuracy: 0.9650 - loss: 0.0816 - val_accuracy: 0.9760 - val_loss: 0.0691
# Epoch 39/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9663 - loss: 0.0825 - val_accuracy: 0.9700 - val_loss: 0.0770
# Epoch 40/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9656 - loss: 0.0806 - val_accuracy: 0.9710 - val_loss: 0.0699
# Epoch 41/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9647 - loss: 0.0823 - val_accuracy: 0.9740 - val_loss: 0.0699
# Epoch 42/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9649 - loss: 0.0838 - val_accuracy: 0.9710 - val_loss: 0.0660
# Epoch 43/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9687 - loss: 0.0768 - val_accuracy: 0.9770 - val_loss: 0.0629
# Epoch 44/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9615 - loss: 0.0819 - val_accuracy: 0.9780 - val_loss: 0.0674
# Epoch 45/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9618 - loss: 0.0876 - val_accuracy: 0.9670 - val_loss: 0.0708
# Epoch 46/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9619 - loss: 0.0856 - val_accuracy: 0.9700 - val_loss: 0.0750
# Epoch 47/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9664 - loss: 0.0781 - val_accuracy: 0.9790 - val_loss: 0.0595
# Epoch 48/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9662 - loss: 0.0803 - val_accuracy: 0.9810 - val_loss: 0.0639
# Epoch 49/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9632 - loss: 0.0806 - val_accuracy: 0.9670 - val_loss: 0.0703
# Epoch 50/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9721 - loss: 0.0702 - val_accuracy: 0.9760 - val_loss: 0.0599
# Epoch 51/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9693 - loss: 0.0694 - val_accuracy: 0.9800 - val_loss: 0.0578
# Epoch 52/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9721 - loss: 0.0725 - val_accuracy: 0.9740 - val_loss: 0.0762
# Epoch 53/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9692 - loss: 0.0717 - val_accuracy: 0.9820 - val_loss: 0.0592
# Epoch 54/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9716 - loss: 0.0661 - val_accuracy: 0.9720 - val_loss: 0.0588
# Epoch 55/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9703 - loss: 0.0707 - val_accuracy: 0.9700 - val_loss: 0.0713
# Epoch 56/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9656 - loss: 0.0729 - val_accuracy: 0.9750 - val_loss: 0.0548
# Epoch 57/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9722 - loss: 0.0706 - val_accuracy: 0.9850 - val_loss: 0.0510
# Epoch 58/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9697 - loss: 0.0638 - val_accuracy: 0.9850 - val_loss: 0.0497
# Epoch 59/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9697 - loss: 0.0678 - val_accuracy: 0.9820 - val_loss: 0.0583
# Epoch 60/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9679 - loss: 0.0763 - val_accuracy: 0.9840 - val_loss: 0.0493
# Epoch 61/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9709 - loss: 0.0718 - val_accuracy: 0.9710 - val_loss: 0.0685
# Epoch 62/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9721 - loss: 0.0670 - val_accuracy: 0.9720 - val_loss: 0.0723
# Epoch 63/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 991us/step - accuracy: 0.9700 - loss: 0.0683 - val_accuracy: 0.9830 - val_loss: 0.0473
# Epoch 64/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9744 - loss: 0.0600 - val_accuracy: 0.9740 - val_loss: 0.0627
# Epoch 65/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 957us/step - accuracy: 0.9736 - loss: 0.0578 - val_accuracy: 0.9850 - val_loss: 0.0526
# Epoch 66/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 961us/step - accuracy: 0.9697 - loss: 0.0626 - val_accuracy: 0.9830 - val_loss: 0.0512
# Epoch 67/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 928us/step - accuracy: 0.9697 - loss: 0.0646 - val_accuracy: 0.9780 - val_loss: 0.0544
# Epoch 68/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9708 - loss: 0.0590 - val_accuracy: 0.9830 - val_loss: 0.0491
# Epoch 69/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9744 - loss: 0.0552 - val_accuracy: 0.9860 - val_loss: 0.0439
# Epoch 70/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9701 - loss: 0.0604 - val_accuracy: 0.9830 - val_loss: 0.0477
# Epoch 71/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 955us/step - accuracy: 0.9748 - loss: 0.0522 - val_accuracy: 0.9860 - val_loss: 0.0461
# Epoch 72/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9749 - loss: 0.0602 - val_accuracy: 0.9800 - val_loss: 0.0475
# Epoch 73/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9772 - loss: 0.0597 - val_accuracy: 0.9790 - val_loss: 0.0541
# Epoch 74/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9771 - loss: 0.0582 - val_accuracy: 0.9760 - val_loss: 0.0570
# Epoch 75/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9734 - loss: 0.0578 - val_accuracy: 0.9760 - val_loss: 0.0523
# Epoch 76/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9722 - loss: 0.0590 - val_accuracy: 0.9760 - val_loss: 0.0527
# Epoch 77/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9776 - loss: 0.0526 - val_accuracy: 0.9820 - val_loss: 0.0431
# Epoch 78/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9772 - loss: 0.0577 - val_accuracy: 0.9830 - val_loss: 0.0401
# Epoch 79/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9777 - loss: 0.0491 - val_accuracy: 0.9730 - val_loss: 0.0584
# Epoch 80/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9777 - loss: 0.0509 - val_accuracy: 0.9840 - val_loss: 0.0410
# Epoch 81/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 994us/step - accuracy: 0.9740 - loss: 0.0597 - val_accuracy: 0.9870 - val_loss: 0.0420
# Epoch 82/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9739 - loss: 0.0529 - val_accuracy: 0.9810 - val_loss: 0.0414
# Epoch 83/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 973us/step - accuracy: 0.9750 - loss: 0.0557 - val_accuracy: 0.9800 - val_loss: 0.0463
# Epoch 84/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9786 - loss: 0.0474 - val_accuracy: 0.9780 - val_loss: 0.0519
# Epoch 85/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9763 - loss: 0.0516 - val_accuracy: 0.9810 - val_loss: 0.0426
# Epoch 86/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9800 - loss: 0.0455 - val_accuracy: 0.9860 - val_loss: 0.0407
# Epoch 87/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9794 - loss: 0.0468 - val_accuracy: 0.9880 - val_loss: 0.0346
# Epoch 88/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9766 - loss: 0.0484 - val_accuracy: 0.9800 - val_loss: 0.0417
# Epoch 89/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9785 - loss: 0.0471 - val_accuracy: 0.9860 - val_loss: 0.0390
# Epoch 90/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9787 - loss: 0.0467 - val_accuracy: 0.9850 - val_loss: 0.0389
# Epoch 91/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9790 - loss: 0.0461 - val_accuracy: 0.9810 - val_loss: 0.0420
# Epoch 92/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 929us/step - accuracy: 0.9812 - loss: 0.0476 - val_accuracy: 0.9740 - val_loss: 0.0518
# Epoch 93/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 912us/step - accuracy: 0.9785 - loss: 0.0499 - val_accuracy: 0.9860 - val_loss: 0.0400
# Epoch 94/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 950us/step - accuracy: 0.9771 - loss: 0.0532 - val_accuracy: 0.9810 - val_loss: 0.0529
# Epoch 95/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 933us/step - accuracy: 0.9771 - loss: 0.0510 - val_accuracy: 0.9810 - val_loss: 0.0505
# Epoch 96/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9765 - loss: 0.0486 - val_accuracy: 0.9800 - val_loss: 0.0423
# Epoch 97/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9732 - loss: 0.0549 - val_accuracy: 0.9750 - val_loss: 0.0488
# Epoch 98/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 4s 886us/step - accuracy: 0.9761 - loss: 0.0522 - val_accuracy: 0.9880 - val_loss: 0.0377
# Epoch 99/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9757 - loss: 0.0496 - val_accuracy: 0.9880 - val_loss: 0.0381
# Epoch 100/100
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 5s 953us/step - accuracy: 0.9794 - loss: 0.0471 - val_accuracy: 0.9720 - val_loss: 0.0805

# %% [markdown]
# If you run the `fit` cell more than once, it will update the fit by running more gradient descent iterations - it won’t start again from the beginning. However, it *will* overwrite your previous model “history” (i.e. the loss and accuracy per epoch from the last call to `fit`).

# %% [markdown]
# ## Visualize output of network

# %% [markdown]
# To see the classification rule our neural network learned, we can plot the predicted class probability over the input space.
#
# We can also plot the response in the each of the hidden units.
#
# Each of the hidden units produces one linear decision region. The final nonlinear region is then formed by taking a weighted combination of these regions.

# %%
#@title Visualize output of each unit

# Prepare coordinate grid
n_plot = 256
xx1, xx2 = np.meshgrid(np.arange(0, n_plot, 1),np.arange(0, n_plot, 1))
X_grid = np.hstack((xx1.reshape(n_plot**2,1), xx2.reshape(n_plot**2,1)))
X_grid = X_grid/(n_plot-1.0)

# Get the response in the hidden units
layer_hid = model.get_layer('hidden')
model1 = Model(inputs=model.get_layer(index=0).input,
               outputs=layer_hid.output)
zhid_plot = model1.predict(X_grid)
zhid_plot = zhid_plot.reshape((n_plot,n_plot,nh))

# Get the weights in the output layer
layer_out = model.get_layer('output')
Wo, bo = layer_out.get_weights()

# Get the response in the output layer
yplot = model.predict(X_grid)
yplot_mat = yplot[:,0].reshape((n_plot, n_plot))

# Plot the output layer
fig = plt.figure(figsize=(15, 6))
plt.subplot(1,nh+1,1)
plt.imshow(np.flipud((yplot_mat.reshape(n_plot, n_plot))), cmap='binary');
plt.xlim(0, n_plot);
plt.ylim(n_plot,0);
plt.xticks([]);
plt.yticks([]);
plt.title("Output")
plt.xlim(0,n_plot);
plt.ylim(n_plot, 0);

# Plot the hidden layers
for i in range(nh):

    plt.subplot(1,nh+1,i+1+1)
    zhid_ploti = (zhid_plot[:,:,i])
    im = plt.imshow(zhid_ploti, vmin=0, vmax=1, cmap='binary')
    im = plt.imshow(np.flipud((zhid_ploti)), cmap='binary');
    plt.xticks([])
    plt.yticks([])
    plt.title('h{0:d}, Wo={1:4.2f}'.format(i+1,Wo[i,0]))
    plt.xlim(0,n_plot);
    plt.ylim(n_plot,0);

fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.9, 0.30, 0.05, 0.4])
fig.colorbar(im, cax=cbar_ax);
# Out:
# 2048/2048 ━━━━━━━━━━━━━━━━━━━━ 1s 492us/step
# 2048/2048 ━━━━━━━━━━━━━━━━━━━━ 1s 419us/step

# %% [markdown]
# We can also check all of the parameters learned by the network:

# %%
layer_hid = model.get_layer('hidden')
Wh, bh = layer_hid.get_weights()
print('Wh=')
print(Wh)
print('bh=')
print(bh)

layer_out = model.get_layer('output')
Wo, bo = layer_out.get_weights()
print('Wo=')
print(Wo)
print('bo=')
print(bo)
# Out:
# Wh=
# [[ 14.745552     4.833574    -7.64885      9.054797   -22.06308
#   -15.16964     -4.58688     14.590145    -3.2380521   -7.7450504 ]
#  [  0.41270176  -0.32934478  -8.762006     9.237785     1.7988988
#    12.685733   -12.768567   -19.563442   -10.210854   -14.154002  ]]
# bh=
# [-12.215318   14.200618    4.5667515 -11.927813   13.058957   -4.687975
#   11.33171     2.817749    9.351514    8.391435 ]
# Wo=
# [[-32.212162 ]
#  [  8.443035 ]
#  [-14.0967865]
#  [-21.048594 ]
#  [-16.43542  ]
#  [-25.730911 ]
#  [ 12.891498 ]
#  [-17.185537 ]
#  [  8.112863 ]
#  [-24.473898 ]]
# bo=
# [4.423839]

# %% [markdown]
# And, we can visualize the training progress vs. epoch:

# %%
import seaborn as sns

plt.figure(figsize=(7,3))

plt.subplot(1,2,1)
train_acc = hist.history['accuracy'];
val_acc = hist.history['val_accuracy'];

nepochs = len(train_acc);
sns.lineplot(x=np.arange(1,nepochs+1), y=train_acc, label='Training accuracy');
sns.lineplot(x=np.arange(1,nepochs+1), y=val_acc, label='Validation accuracy');
plt.xlabel('Epoch');
plt.ylabel('Accuracy');

plt.subplot(1,2,2)
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']
sns.lineplot(x=np.arange(1,nepochs+1), y=train_loss, label='Training loss');
sns.lineplot(x=np.arange(1,nepochs+1), y=val_loss, label='Validation loss');
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.tight_layout()

# %% [markdown]
# ## Measure performance on test set

# %%
y_pred = model.predict(X_test)
y_pred = np.round(y_pred).astype(int)
y_pred = y_pred.squeeze()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step

# %%
np.mean((y_pred == y_test).astype(int))
# Out:
# np.float64(0.9682)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.scatter(x=X_test[:,0], y=X_test[:,1], c=y_pred, cmap='binary', edgecolors= "gray")
plt.xlabel("x1");
plt.ylabel("x2");
plt.title("Predictions for test data");

plt.subplot(1,2,2)
plt.scatter(x=X_test[:,0], y=X_test[:,1], c=y_test, cmap='binary', edgecolors= "gray")
plt.xlabel("x1");
plt.ylabel("x2");
plt.title("Actual test data");

# %% [markdown]
# ## Things to try
#
# -   What happens if we use `linear` activations, instead of sigmoid?
# -   When do we need to use a large number of hidden units?
# -   Try to adjust the learning rate and batch size. What is the effect?
# -   What should you do if you want to train the model for a few more epochs? (What happens to your history when you do that?)
# -   What should you do if you want to change the model architecture and train it from scratch?
