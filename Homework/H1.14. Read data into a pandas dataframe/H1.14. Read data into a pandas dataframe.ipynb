# %% [markdown]
# # Load in data

# %% [markdown]
# In this question, you will use `pandas`'s [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) to read in a `file dataset_Parkinsons.csv`. However, the default arguments (i.e. only specifying the filename) won't load the data correctly. You will need to decide which arguments to specify, and what values to use, to read in the data correctly, including all data rows and correct column headings.
#
# Note: the column headers you should use are in the second row of the data file.
#
# In the notebook attached to this example, your code should produce the following result:
#
# | Name |	Type |	Description |
# | --- | --- | --- |
# |`df`|	pandas dataframe |	Data from the file, correctly read into a dataframe.|

# %%
import pandas as pd

# %% [markdown]
# In the following cell, select the appropriate arguments to `pd.read_csv` to load your data into a `pandas` dataframe.

# %%
#grade (write your code in this cell and DO NOT DELETE THIS LINE)
df = pd.read_csv('dataset_Parkinsons.csv', skiprows=1)

# %% [markdown]
# You can test your work by looking at the output in the next cell:

# %%
df.head()
# Out:
#   Participant code  Age (years) Gender  \
# 0             PD01           58      F
# 1             PD02           68      F
# 2             PD03           68      M
# 3             PD04           75      M
# 4             PD05           61      M
#
#   Positive history of Parkinson disease in family  \
# 0                                              No
# 1                                              No
# 2                                              No
# 3                                              No
# 4                                             Yes
#
#   Age of disease onset (years)  \
# 0                           56
# 1                           67
# 2                           67
# 3                           73
# 4                           60
#
#   Duration of disease from first symptoms (years) Antidepressant therapy  \
# 0                                               2                     No
# 1                                               1                     No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 65 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   Participant code                                                                      130 non-null    object
#  1   Age (years)                                                                           130 non-null    int64
#  2   Gender                                                                                130 non-null    object
#  3   Positive history of Parkinson disease in family                                       130 non-null    object
#  4   Age of disease onset (years)                                                          130 non-null    object
# ...
